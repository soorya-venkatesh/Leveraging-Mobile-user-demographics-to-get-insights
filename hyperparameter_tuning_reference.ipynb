# %% [markdown]
# # Hyperparameter Tuning using HyperDrive
#
# TODO: Import Dependencies. In the cell below, import all the dependencies that you will need to complete the project.

# %%
# import all the dependencies
import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.core.dataset import Dataset
from azureml.data.dataset_factory import TabularDatasetFactory
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException
from azureml.core.model import Model
from azureml.core import Environment, ScriptRunConfig
from azureml.widgets import RunDetails
from azureml.train.hyperdrive.run import PrimaryMetricGoal
from azureml.train.hyperdrive.policy import BanditPolicy, MedianStoppingPolicy
from azureml.train.hyperdrive.sampling import RandomParameterSampling
from azureml.train.hyperdrive.runconfig import HyperDriveConfig
from azureml.train.hyperdrive.parameter_expressions import uniform, choice
from azureml.core import ScriptRunConfig
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import os
import shutil

ws = Workspace.from_config()

# %%
# Create compute cluster
# Use vm_size = "Standard_D2_V2" in your provisioning configuration.
# max_nodes should be no greater than 4.
# source: https://docs.microsoft.com/en-us/python/api/azureml-core/azureml.core.compute.amlcompute(class)?view=azure-ml-py

cpu_cluster_name = "cpu-cluster"

# Verify that cluster does not exist already
try:
    cpu_cluster = ComputeTarget(workspace=ws, name=cpu_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',
                                                           max_nodes=4)
    cpu_cluster = ComputeTarget.create(ws, cpu_cluster_name, compute_config)

cpu_cluster.wait_for_completion(show_output=True)
# Out:
# InProgress.......
# SucceededProvisioning operation finished, operation "Succeeded"
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## Dataset
#
# ### Overview
# The following project uses data from Kaggle: https://www.kaggle.com/uciml/default-of-credit-card-clients-dataset.
# This dataset contains information on default payments, demographic factors, credit data, history of payment, and bill statements of credit card clients in Taiwan from April 2005 to September 2005. The description of each column can be found on kaggle. Our task will be to create ML models that will predict whether or not someone will default their payment in the following month.
#
# The data is stored is stored as csv file in the current folder. We will use python SDK to upload and register the data in Azure.

# %%
ws = Workspace.from_config()

# choose a name for experiment
experiment_name = 'azureml-capstone'

experiment=Experiment(ws, experiment_name)

# %%
ds_path = "https://raw.githubusercontent.com/albertwibowo/nd00333-capstone/master/starter_file/UCI_Credit_Card.csv"
ds = TabularDatasetFactory.from_delimited_files(path=ds_path)

df = ds.to_pandas_dataframe()
df.describe()
# Out:
#             limit_bal           sex     education      marriage           age  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    167484.322667      1.603733      1.853133      1.551867     35.485500
# std     129747.661567      0.489129      0.790349      0.521970      9.217904
# min      10000.000000      1.000000      0.000000      0.000000     21.000000
# 25%      50000.000000      1.000000      1.000000      1.000000     28.000000
# 50%     140000.000000      2.000000      2.000000      2.000000     34.000000
# 75%     240000.000000      2.000000      2.000000      2.000000     41.000000
# max    1000000.000000      2.000000      6.000000      3.000000     79.000000
#
#               pay_0         pay_2         pay_3         pay_4         pay_5  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      -0.016700     -0.133767     -0.166200     -0.220667     -0.266200
# std        1.123802      1.197186      1.196868      1.169139      1.133187
# min       -2.000000     -2.000000     -2.000000     -2.000000     -2.000000
# 25%       -1.000000     -1.000000     -1.000000     -1.000000     -1.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        8.000000      8.000000      8.000000      8.000000      8.000000
#
#        ...      bill_amt4      bill_amt5      bill_amt6       pay_amt1  \
# count  ...   30000.000000   30000.000000   30000.000000   30000.000000
# mean   ...   43262.948967   40311.400967   38871.760400    5663.580500
# std    ...   64332.856134   60797.155770   59554.107537   16563.280354
# min    ... -170000.000000  -81334.000000 -339603.000000       0.000000
# 25%    ...    2326.750000    1763.000000    1256.000000    1000.000000
# 50%    ...   19052.000000   18104.500000   17071.000000    2100.000000
# 75%    ...   54506.000000   50190.500000   49198.250000    5006.000000
# max    ...  891586.000000  927171.000000  961664.000000  873552.000000
#
#            pay_amt2      pay_amt3       pay_amt4       pay_amt5  \
# count  3.000000e+04   30000.00000   30000.000000   30000.000000
# mean   5.921163e+03    5225.68150    4826.076867    4799.387633
# std    2.304087e+04   17606.96147   15666.159744   15278.305679
# min    0.000000e+00       0.00000       0.000000       0.000000
# 25%    8.330000e+02     390.00000     296.000000     252.500000
# 50%    2.009000e+03    1800.00000    1500.000000    1500.000000
# 75%    5.000000e+03    4505.00000    4013.250000    4031.500000
# max    1.684259e+06  896040.00000  621000.000000  426529.000000
#
#             pay_amt6  default.payment.next.month
# count   30000.000000                30000.000000
# mean     5215.502567                    0.221200
# std     17777.465775                    0.415062
# min         0.000000                    0.000000
# 25%       117.750000                    0.000000
# 50%      1500.000000                    0.000000
# 75%      4000.000000                    0.000000
# max    528666.000000                    1.000000
#
# [8 rows x 24 columns]

# %%
from azureml.core.dataset import Dataset
from sklearn.model_selection import train_test_split

key = 'credit_default_dataset'
if key in ws.datasets.keys():
    dataset = ws.datasets[key]
    print("The dataset was found!")

else:
    url = ds_path
    dataset = Dataset.Tabular.from_delimited_files(url)
    dataset = dataset.register(ws,key)

df = dataset.to_pandas_dataframe()
train, test = train_test_split(df, shuffle=True, random_state=42)
train.to_csv('train.csv', index = False)

datastore = ws.get_default_datastore()
datastore.upload_files(files = ['./train.csv'])

train = Dataset.Tabular.from_delimited_files([(datastore, 'train.csv')])
# Out:
# Uploading an estimated of 1 files
# Uploading ./train.csv
# Uploaded ./train.csv, 1 files out of an estimated total of 1
# Uploaded 1 files

# %%
# %%writefile conda_dependencies.yml
# dependencies:
# - python=3.6.4
# - scikit-learn
# - pandas
# - numpy
# - pip:
#   - azureml-defaults
# Out:
# Overwriting conda_dependencies.yml

# %% [markdown]
# ## Hyperdrive Configuration
#
# TODO: Explain the model you are using and the reason for chosing the different hyperparameters, termination policy and config settings.

# %%
early_termination_policy = BanditPolicy(slack_factor=0.15, evaluation_interval=1, delay_evaluation=10)

# parameter sampler
param_sampling = RandomParameterSampling( {
    'n_estimators': choice(100, 200, 500),
    'learning_rate': uniform(0.1, 1.0),
    'max_depth': choice(1, 3, 5)
    }
)

sklearn_env = Environment.from_conda_specification(name="sklearn-env",file_path="./conda_dependencies.yml")

# configure and submit your training run
run_config = ScriptRunConfig(source_directory='.',
                            script='train.py',
                            compute_target=cpu_cluster,
                            environment=sklearn_env)

hyperdrive_run_config = HyperDriveConfig(run_config=run_config,
                                     hyperparameter_sampling=param_sampling, 
                                     policy=early_termination_policy,
                                     primary_metric_name='AUC_weighted',
                                     primary_metric_goal=PrimaryMetricGoal.MAXIMIZE,
                                     max_total_runs=12,
                                     max_concurrent_runs=4)

# %%
#TODO: Submit your experiment
run = experiment.submit(config=hyperdrive_run_config)

# %% [markdown]
# ## Run Details
#
# OPTIONAL: Write about the different models trained and their performance. Why do you think some models did better than others?
#
# TODO: In the cell below, use the `RunDetails` widget to show the different experiments.

# %% [markdown]
# ## Best Model
#
# TODO: In the cell below, get the best model from the hyperdrive experiments and display all the properties of the model.

# %%
best_run = run.get_best_run_by_primary_metric()
print('Best model runId: ' + str(best_run.get_details()['runId']),
      'Best model hyperparameters: ' + str(best_run.get_details()['runDefinition']['arguments']), 
      'Best model  weighted AUC: ' + str(best_run.get_metrics()['AUC_weighted']), sep = '\n\n')
# Out:
# Best model runId: HD_086c738f-33d5-484a-9596-021900feab2f_7
#
# Best model hyperparameters: ['--learning_rate', '0.1429903627672755', '--max_depth', '1', '--n_estimators', '500']
#
# Best model  weighted AUC: 0.7774262768028579

# %%
best_run
# Out:
# Run(Experiment: azureml-capstone,
# Id: HD_086c738f-33d5-484a-9596-021900feab2f_7,
# Type: azureml.scriptrun,
# Status: Completed)

# %%
#TODO: Save the best model

model = best_run.register_model(model_name='credit_hyperdrive_model', model_path='outputs/model.joblib')
model.download(target_dir='outputs_hyperdrive', exist_ok=True)
# Out:
# 'outputs_hyperdrive/model.joblib'

# %% [markdown]
# ## Model Deployment
#
# Remember you have to deploy only one of the two models you trained but you still need to register both the models. Perform the steps in the rest of this notebook only if you wish to deploy this model.
#
# TODO: In the cell below, register the model, create an inference config and deploy the model as a web service.

# %%
from azureml.core.model import InferenceConfig
from azureml.core.webservice import Webservice, AciWebservice

inference_config = InferenceConfig(entry_script="score.py", environment = sklearn_env)

deployment_config = AciWebservice.deploy_configuration(cpu_cores=1, memory_gb = 1,enable_app_insights = True)

# %%
service=Model.deploy(workspace=ws,
                    name="credit-hyper-service",
                    models=[model],
                    inference_config=inference_config,
                    deployment_config=deployment_config)

service.wait_for_deployment(show_output=True)
# Out:
# DEBUG:azureml.ArtifactsClient.batch_create_empty_artifacts-async:False:[START]
# DEBUG:azureml.ArtifactsClient:ClientBase: Calling batch_create_empty_artifacts with url /artifact/v2.0/subscriptions/{subscriptionId}/resourceGroups/{resourceGroupName}/providers/Microsoft.MachineLearningServices/workspaces/{workspaceName}/artifacts/batch/metadata/{origin}/{container}
# DEBUG:msrest.service_client:Accept header absent and forced to application/json
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): 127.0.1.1:46808
# DEBUG:urllib3.connectionpool:http://127.0.1.1:46808 "GET /MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01 HTTP/1.1" 200 2018
# DEBUG:msrestazure.azure_active_directory:MSI: Retrieving a token from http://127.0.1.1:46808/MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01
# DEBUG:msrestazure.azure_active_directory:MSI: token retrieved
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): 127.0.1.1:46808
# DEBUG:urllib3.connectionpool:http://127.0.1.1:46808 "GET /MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01 HTTP/1.1" 200 2018
# DEBUG:msrestazure.azure_active_directory:MSI: Retrieving a token from http://127.0.1.1:46808/MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01
# DEBUG:msrestazure.azure_active_directory:MSI: token retrieved
# DEBUG:msrest.http_logger:Request URL: 'https://westeurope.experiments.azureml.net/artifact/v2.0/subscriptions/9d6e9855-22d9-4bd1-9b10-1f48fc786ab7/resourceGroups/udacity_capstone/providers/Microsoft.MachineLearningServices/workspaces/udacitycapstone/artifacts/batch/metadata/LocalUpload/86043484'
# DEBUG:msrest.http_logger:Request method: 'POST'
# DEBUG:msrest.http_logger:Request headers:
# DEBUG:msrest.http_logger:    'Accept': 'application/json'
# DEBUG:msrest.http_logger:    'Content-Type': 'application/json-patch+json; charset=utf-8'
# DEBUG:msrest.http_logger:    'x-ms-client-request-id': '09b2d8b9-7be9-47eb-9432-5292bd6b0285'
# DEBUG:msrest.http_logger:    'request-id': '09b2d8b9-7be9-47eb-9432-5292bd6b0285'
# DEBUG:msrest.http_logger:    'Content-Length': '39'
# DEBUG:msrest.http_logger:    'User-Agent': 'python/3.6.9 (Linux-5.4.0-1056-azure-x86_64-with-debian-buster-sid) msrest/0.6.21 azureml._restclient/core.1.34.0 DSVM_workstation/47506801_21.09.20 azureml-sdk-core/1.34.0'
# DEBUG:msrest.http_logger:Request body:
# DEBUG:msrest.http_logger:{"paths": [{"path": "tmpdmn0muxm.py"}]}
# DEBUG:msrest.universal_http:Configuring redirects: allow=True, max=30
# DEBUG:msrest.universal_http:Configuring request: timeout=100, verify=True, cert=None
# DEBUG:msrest.universal_http:Configuring proxies: ''
# DEBUG:msrest.universal_http:Evaluate proxies against ENV settings: True
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): westeurope.experiments.azureml.net:443
# DEBUG:urllib3.connectionpool:https://westeurope.experiments.azureml.net:443 "POST /artifact/v2.0/subscriptions/9d6e9855-22d9-4bd1-9b10-1f48fc786ab7/resourceGroups/udacity_capstone/providers/Microsoft.MachineLearningServices/workspaces/udacitycapstone/artifacts/batch/metadata/LocalUpload/86043484 HTTP/1.1" 200 None
# DEBUG:msrest.http_logger:Response status: 200
# DEBUG:msrest.http_logger:Response headers:
# DEBUG:msrest.http_logger:    'Date': 'Sat, 13 Nov 2021 16:44:42 GMT'
# DEBUG:msrest.http_logger:    'Content-Type': 'application/json; charset=utf-8'
# DEBUG:msrest.http_logger:    'Transfer-Encoding': 'chunked'
# DEBUG:msrest.http_logger:    'Connection': 'keep-alive'
# DEBUG:msrest.http_logger:    'Vary': 'Accept-Encoding'
# DEBUG:msrest.http_logger:    'Request-Context': 'appId=cid-v1:6a27ce65-5555-41a3-85f7-b7a1ce31fd6b'
# DEBUG:msrest.http_logger:    'x-ms-response-type': 'standard'
# DEBUG:msrest.http_logger:    'Strict-Transport-Security': 'max-age=15724800; includeSubDomains; preload'
# DEBUG:msrest.http_logger:    'X-Content-Type-Options': 'nosniff'
# DEBUG:msrest.http_logger:    'x-request-time': '1.349'
# DEBUG:msrest.http_logger:    'Content-Encoding': 'gzip'
# DEBUG:msrest.http_logger:Response content:
# DEBUG:msrest.http_logger:{
#   "artifacts": {
#     "tmpdmn0muxm.py": {
#       "artifactId": "LocalUpload/86043484/tmpdmn0muxm.py",
#       "origin": "LocalUpload",
#       "container": "86043484",
#       "path": "tmpdmn0muxm.py",
#       "etag": "\"440150b0-0000-0d00-0000-618feb790000\"",
#       "createdTime": "2021-11-13T16:44:41.7876664+00:00",
#       "dataPath": null,
#       "tags": {}
#     }
#   },
#   "artifactContentInformation": {
#     "tmpdmn0muxm.py": {
#       "contentUri": "https://udacityazure.blob.core.windows.net/azureml/LocalUpload/86043484/tmpdmn0muxm.py?sv=2019-07-07&sr=b&sig=Ul3Xa7rThR%2F8e5eqBpjxx59Zh6Adyb44t7%2FXt3EfHhI%3D&skoid=33158cef-8900-4fe8-a8d5-1d42a9ac1225&sktid=3b230bda-fd85-4c71-87b7-bb8a2e9bbe9f&skt=2021-11-13T14%3A11%3A11Z&ske=2021-11-14T22%3A21%3A11Z&sks=b&skv=2019-07-07&st=2021-11-13T16%3A34%3A42Z&se=2021-11-14T16%3A44%3A42Z&sp=rcw",
#       "origin": "LocalUpload",
#       "container": "86043484",
#       "path": "tmpdmn0muxm.py",
#       "tags": {}
#     }
#   },
#   "errors": {}
# }
# DEBUG:azureml.ArtifactsClient.batch_create_empty_artifacts-async:False:[STOP]
# DEBUG:azureml._restclient.clientbase:ClientBase: Calling create_blob_from_stream with url None
# DEBUG:urllib3.connectionpool:Resetting dropped connection: udacityazure.blob.core.windows.net
# DEBUG:urllib3.connectionpool:https://udacityazure.blob.core.windows.net:443 "PUT /azureml/LocalUpload/86043484/tmpdmn0muxm.py?comp=block&blockid=TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQSUzRA%3D%3D&timeout=30&sv=2019-07-07&sr=b&sig=Ul3Xa7rThR%2F8e5eqBpjxx59Zh6Adyb44t7%2FXt3EfHhI%3D&skoid=33158cef-8900-4fe8-a8d5-1d42a9ac1225&sktid=3b230bda-fd85-4c71-87b7-bb8a2e9bbe9f&skt=2021-11-13T14%3A11%3A11Z&ske=2021-11-14T22%3A21%3A11Z&sks=b&skv=2019-07-07&st=2021-11-13T16%3A34%3A42Z&se=2021-11-14T16%3A44%3A42Z&sp=rcw HTTP/1.1" 201 0
# DEBUG:urllib3.connectionpool:https://udacityazure.blob.core.windows.net:443 "PUT /azureml/LocalUpload/86043484/tmpdmn0muxm.py?comp=blocklist&timeout=30&sv=2019-07-07&sr=b&sig=Ul3Xa7rThR%2F8e5eqBpjxx59Zh6Adyb44t7%2FXt3EfHhI%3D&skoid=33158cef-8900-4fe8-a8d5-1d42a9ac1225&sktid=3b230bda-fd85-4c71-87b7-bb8a2e9bbe9f&skt=2021-11-13T14%3A11%3A11Z&ske=2021-11-14T22%3A21%3A11Z&sks=b&skv=2019-07-07&st=2021-11-13T16%3A34%3A42Z&se=2021-11-14T16%3A44%3A42Z&sp=rcw HTTP/1.1" 201 0
# DEBUG:urllib3.connectionpool:https://udacityazure.blob.core.windows.net:443 "HEAD /azureml/LocalUpload/86043484/tmpdmn0muxm.py?sv=2019-07-07&sr=b&sig=Ul3Xa7rThR%2F8e5eqBpjxx59Zh6Adyb44t7%2FXt3EfHhI%3D&skoid=33158cef-8900-4fe8-a8d5-1d42a9ac1225&sktid=3b230bda-fd85-4c71-87b7-bb8a2e9bbe9f&skt=2021-11-13T14%3A11%3A11Z&ske=2021-11-14T22%3A21%3A11Z&sks=b&skv=2019-07-07&st=2021-11-13T16%3A34%3A42Z&se=2021-11-14T16%3A44%3A42Z&sp=rcw HTTP/1.1" 200 0
# DEBUG:azureml._file_utils.upload:Uploaded blob LocalUpload/86043484/tmpdmn0muxm.py with size 1064, file size 1064.
# DEBUG:azureml.ArtifactsClient.batch_create_empty_artifacts-async:False:[START]
# DEBUG:azureml.ArtifactsClient:ClientBase: Calling batch_create_empty_artifacts with url /artifact/v2.0/subscriptions/{subscriptionId}/resourceGroups/{resourceGroupName}/providers/Microsoft.MachineLearningServices/workspaces/{workspaceName}/artifacts/batch/metadata/{origin}/{container}
# DEBUG:msrest.service_client:Accept header absent and forced to application/json
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): 127.0.1.1:46808
# DEBUG:urllib3.connectionpool:http://127.0.1.1:46808 "GET /MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01 HTTP/1.1" 200 2018
# DEBUG:msrestazure.azure_active_directory:MSI: Retrieving a token from http://127.0.1.1:46808/MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01
# DEBUG:msrestazure.azure_active_directory:MSI: token retrieved
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): 127.0.1.1:46808
# DEBUG:urllib3.connectionpool:http://127.0.1.1:46808 "GET /MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01 HTTP/1.1" 200 2018
# DEBUG:msrestazure.azure_active_directory:MSI: Retrieving a token from http://127.0.1.1:46808/MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01
# DEBUG:msrestazure.azure_active_directory:MSI: token retrieved
# DEBUG:msrest.http_logger:Request URL: 'https://westeurope.experiments.azureml.net/artifact/v2.0/subscriptions/9d6e9855-22d9-4bd1-9b10-1f48fc786ab7/resourceGroups/udacity_capstone/providers/Microsoft.MachineLearningServices/workspaces/udacitycapstone/artifacts/batch/metadata/LocalUpload/9db04d98'
# DEBUG:msrest.http_logger:Request method: 'POST'
# DEBUG:msrest.http_logger:Request headers:
# DEBUG:msrest.http_logger:    'Accept': 'application/json'
# DEBUG:msrest.http_logger:    'Content-Type': 'application/json-patch+json; charset=utf-8'
# DEBUG:msrest.http_logger:    'x-ms-client-request-id': '4ffb56fa-cb68-4ac6-b72b-06e7e9461dab'
# DEBUG:msrest.http_logger:    'request-id': '4ffb56fa-cb68-4ac6-b72b-06e7e9461dab'
# DEBUG:msrest.http_logger:    'Content-Length': '33'
# DEBUG:msrest.http_logger:    'User-Agent': 'python/3.6.9 (Linux-5.4.0-1056-azure-x86_64-with-debian-buster-sid) msrest/0.6.21 azureml._restclient/core.1.34.0 DSVM_workstation/47506801_21.09.20 azureml-sdk-core/1.34.0'
# DEBUG:msrest.http_logger:Request body:
# DEBUG:msrest.http_logger:{"paths": [{"path": "score.py"}]}
# DEBUG:msrest.universal_http:Configuring redirects: allow=True, max=30
# DEBUG:msrest.universal_http:Configuring request: timeout=100, verify=True, cert=None
# DEBUG:msrest.universal_http:Configuring proxies: ''
# DEBUG:msrest.universal_http:Evaluate proxies against ENV settings: True
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): westeurope.experiments.azureml.net:443
# DEBUG:urllib3.connectionpool:https://westeurope.experiments.azureml.net:443 "POST /artifact/v2.0/subscriptions/9d6e9855-22d9-4bd1-9b10-1f48fc786ab7/resourceGroups/udacity_capstone/providers/Microsoft.MachineLearningServices/workspaces/udacitycapstone/artifacts/batch/metadata/LocalUpload/9db04d98 HTTP/1.1" 200 None
# DEBUG:msrest.http_logger:Response status: 200
# DEBUG:msrest.http_logger:Response headers:
# DEBUG:msrest.http_logger:    'Date': 'Sat, 13 Nov 2021 16:44:45 GMT'
# DEBUG:msrest.http_logger:    'Content-Type': 'application/json; charset=utf-8'
# DEBUG:msrest.http_logger:    'Transfer-Encoding': 'chunked'
# DEBUG:msrest.http_logger:    'Connection': 'keep-alive'
# DEBUG:msrest.http_logger:    'Vary': 'Accept-Encoding'
# DEBUG:msrest.http_logger:    'Request-Context': 'appId=cid-v1:6a27ce65-5555-41a3-85f7-b7a1ce31fd6b'
# DEBUG:msrest.http_logger:    'x-ms-response-type': 'standard'
# DEBUG:msrest.http_logger:    'Strict-Transport-Security': 'max-age=15724800; includeSubDomains; preload'
# DEBUG:msrest.http_logger:    'X-Content-Type-Options': 'nosniff'
# DEBUG:msrest.http_logger:    'x-request-time': '1.336'
# DEBUG:msrest.http_logger:    'Content-Encoding': 'gzip'
# DEBUG:msrest.http_logger:Response content:
# DEBUG:msrest.http_logger:{
#   "artifacts": {
#     "score.py": {
#       "artifactId": "LocalUpload/9db04d98/score.py",
#       "origin": "LocalUpload",
#       "container": "9db04d98",
#       "path": "score.py",
#       "etag": "\"f703c4de-0000-0d00-0000-618feb7c0000\"",
#       "createdTime": "2021-11-13T16:44:44.6898214+00:00",
#       "dataPath": null,
#       "tags": {}
#     }
#   },
#   "artifactContentInformation": {
#     "score.py": {
#       "contentUri": "https://udacityazure.blob.core.windows.net/azureml/LocalUpload/9db04d98/score.py?sv=2019-07-07&sr=b&sig=HX9r7Xglyi5GDWcfAHPfaijZ2xT%2FbS8Q2v%2FSzHm5dI0%3D&skoid=33158cef-8900-4fe8-a8d5-1d42a9ac1225&sktid=3b230bda-fd85-4c71-87b7-bb8a2e9bbe9f&skt=2021-11-13T14%3A11%3A11Z&ske=2021-11-14T22%3A21%3A11Z&sks=b&skv=2019-07-07&st=2021-11-13T16%3A34%3A45Z&se=2021-11-14T16%3A44%3A45Z&sp=rcw",
#       "origin": "LocalUpload",
#       "container": "9db04d98",
#       "path": "score.py",
#       "tags": {}
#     }
#   },
#   "errors": {}
# }
# DEBUG:azureml.ArtifactsClient.batch_create_empty_artifacts-async:False:[STOP]
# DEBUG:azureml._restclient.clientbase:ClientBase: Calling create_blob_from_stream with url None
# DEBUG:urllib3.connectionpool:https://udacityazure.blob.core.windows.net:443 "PUT /azureml/LocalUpload/9db04d98/score.py?comp=block&blockid=TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQXdNREF3TURBd01EQSUzRA%3D%3D&timeout=30&sv=2019-07-07&sr=b&sig=HX9r7Xglyi5GDWcfAHPfaijZ2xT%2FbS8Q2v%2FSzHm5dI0%3D&skoid=33158cef-8900-4fe8-a8d5-1d42a9ac1225&sktid=3b230bda-fd85-4c71-87b7-bb8a2e9bbe9f&skt=2021-11-13T14%3A11%3A11Z&ske=2021-11-14T22%3A21%3A11Z&sks=b&skv=2019-07-07&st=2021-11-13T16%3A34%3A45Z&se=2021-11-14T16%3A44%3A45Z&sp=rcw HTTP/1.1" 201 0
# DEBUG:urllib3.connectionpool:https://udacityazure.blob.core.windows.net:443 "PUT /azureml/LocalUpload/9db04d98/score.py?comp=blocklist&timeout=30&sv=2019-07-07&sr=b&sig=HX9r7Xglyi5GDWcfAHPfaijZ2xT%2FbS8Q2v%2FSzHm5dI0%3D&skoid=33158cef-8900-4fe8-a8d5-1d42a9ac1225&sktid=3b230bda-fd85-4c71-87b7-bb8a2e9bbe9f&skt=2021-11-13T14%3A11%3A11Z&ske=2021-11-14T22%3A21%3A11Z&sks=b&skv=2019-07-07&st=2021-11-13T16%3A34%3A45Z&se=2021-11-14T16%3A44%3A45Z&sp=rcw HTTP/1.1" 201 0
# DEBUG:urllib3.connectionpool:https://udacityazure.blob.core.windows.net:443 "HEAD /azureml/LocalUpload/9db04d98/score.py?sv=2019-07-07&sr=b&sig=HX9r7Xglyi5GDWcfAHPfaijZ2xT%2FbS8Q2v%2FSzHm5dI0%3D&skoid=33158cef-8900-4fe8-a8d5-1d42a9ac1225&sktid=3b230bda-fd85-4c71-87b7-bb8a2e9bbe9f&skt=2021-11-13T14%3A11%3A11Z&ske=2021-11-14T22%3A21%3A11Z&sks=b&skv=2019-07-07&st=2021-11-13T16%3A34%3A45Z&se=2021-11-14T16%3A44%3A45Z&sp=rcw HTTP/1.1" 200 0
# DEBUG:azureml._file_utils.upload:Uploaded blob LocalUpload/9db04d98/score.py with size 580, file size 580.
# DEBUG:azureml.HyperDriveRun#HD_086c738f-33d5-484a-9596-021900feab2f.RunHistoryFacade.RunClient.get-async:False:[START]
# DEBUG:azureml.HyperDriveRun#HD_086c738f-33d5-484a-9596-021900feab2f.RunHistoryFacade.RunClient:ClientBase: Calling get with url /history/v1.0/subscriptions/{subscriptionId}/resourceGroups/{resourceGroupName}/providers/Microsoft.MachineLearningServices/workspaces/{workspaceName}/experiments/{experimentName}/runs/{runId}
# DEBUG:msrest.service_client:Accept header absent and forced to application/json
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): 127.0.1.1:46808
# DEBUG:urllib3.connectionpool:http://127.0.1.1:46808 "GET /MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01 HTTP/1.1" 200 2018
# DEBUG:msrestazure.azure_active_directory:MSI: Retrieving a token from http://127.0.1.1:46808/MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01
# DEBUG:msrestazure.azure_active_directory:MSI: token retrieved
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): 127.0.1.1:46808
# DEBUG:urllib3.connectionpool:http://127.0.1.1:46808 "GET /MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01 HTTP/1.1" 200 2018
# DEBUG:msrestazure.azure_active_directory:MSI: Retrieving a token from http://127.0.1.1:46808/MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01
# DEBUG:msrestazure.azure_active_directory:MSI: token retrieved
# DEBUG:msrest.http_logger:Request URL: 'https://westeurope.experiments.azureml.net/history/v1.0/subscriptions/9d6e9855-22d9-4bd1-9b10-1f48fc786ab7/resourceGroups/udacity_capstone/providers/Microsoft.MachineLearningServices/workspaces/udacitycapstone/experiments/azureml-capstone/runs/HD_086c738f-33d5-484a-9596-021900feab2f'
# DEBUG:msrest.http_logger:Request method: 'GET'
# DEBUG:msrest.http_logger:Request headers:
# DEBUG:msrest.http_logger:    'Accept': 'application/json'
# DEBUG:msrest.http_logger:    'Content-Type': 'application/json; charset=utf-8'
# DEBUG:msrest.http_logger:    'x-ms-client-request-id': 'f3f89f23-3a67-4a28-8eb8-4860519578ad'
# DEBUG:msrest.http_logger:    'request-id': 'f3f89f23-3a67-4a28-8eb8-4860519578ad'
# DEBUG:msrest.http_logger:    'User-Agent': 'python/3.6.9 (Linux-5.4.0-1056-azure-x86_64-with-debian-buster-sid) msrest/0.6.21 azureml._restclient/core.1.34.0 DSVM_workstation/47506801_21.09.20 azureml-sdk-core/1.34.0'
# DEBUG:msrest.http_logger:Request body:
# DEBUG:msrest.http_logger:None
# DEBUG:msrest.universal_http:Configuring redirects: allow=True, max=30
# DEBUG:msrest.universal_http:Configuring request: timeout=100, verify=True, cert=None
# DEBUG:msrest.universal_http:Configuring proxies: ''
# DEBUG:msrest.universal_http:Evaluate proxies against ENV settings: True
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): westeurope.experiments.azureml.net:443
# DEBUG:urllib3.connectionpool:https://westeurope.experiments.azureml.net:443 "GET /history/v1.0/subscriptions/9d6e9855-22d9-4bd1-9b10-1f48fc786ab7/resourceGroups/udacity_capstone/providers/Microsoft.MachineLearningServices/workspaces/udacitycapstone/experiments/azureml-capstone/runs/HD_086c738f-33d5-484a-9596-021900feab2f HTTP/1.1" 200 None
# DEBUG:msrest.http_logger:Response status: 200
# DEBUG:msrest.http_logger:Response headers:
# DEBUG:msrest.http_logger:    'Date': 'Sat, 13 Nov 2021 16:44:54 GMT'
# DEBUG:msrest.http_logger:    'Content-Type': 'application/json; charset=utf-8'
# DEBUG:msrest.http_logger:    'Transfer-Encoding': 'chunked'
# DEBUG:msrest.http_logger:    'Connection': 'keep-alive'
# DEBUG:msrest.http_logger:    'Vary': 'Accept-Encoding'
# DEBUG:msrest.http_logger:    'Request-Context': 'appId=cid-v1:6a27ce65-5555-41a3-85f7-b7a1ce31fd6b'
# DEBUG:msrest.http_logger:    'x-ms-response-type': 'standard'
# DEBUG:msrest.http_logger:    'Strict-Transport-Security': 'max-age=15724800; includeSubDomains; preload'
# DEBUG:msrest.http_logger:    'X-Content-Type-Options': 'nosniff'
# DEBUG:msrest.http_logger:    'x-request-time': '0.040'
# DEBUG:msrest.http_logger:    'Content-Encoding': 'gzip'
# DEBUG:msrest.http_logger:Response content:
# DEBUG:msrest.http_logger:{
#   "runNumber": 37,
#   "rootRunId": "HD_086c738f-33d5-484a-9596-021900feab2f",
#   "createdUtc": "2021-11-13T15:21:48.8529293+00:00",
#   "createdBy": {
#     "userObjectId": "d58acee8-35d9-4a26-9c33-6fc6220d8779",
#     "userPuId": "10032001A71563D6",
#     "userIdp": "live.com",
#     "userAltSecId": "1:live.com:00037FFE02800449",
#     "userIss": "https://sts.windows.net/3b230bda-fd85-4c71-87b7-bb8a2e9bbe9f/",
#     "userTenantId": "3b230bda-fd85-4c71-87b7-bb8a2e9bbe9f",
#     "userName": "albert wibowo",
#     "upn": null
#   },
#   "userId": "d58acee8-35d9-4a26-9c33-6fc6220d8779",
#   "token": null,
#   "tokenExpiryTimeUtc": null,
#   "error": null,
#   "warnings": null,
#   "revision": 18,
#   "statusRevision": 0,
#   "runUuid": "260cc845-74d2-47eb-b8d7-113f12619075",
#   "parentRunUuid": null,
#   "rootRunUuid": "260cc845-74d2-47eb-b8d7-113f12619075",
#   "hasVirtualParent": false,
#   "lastStartTimeUtc": null,
#   "currentComputeTime": null,
#   "computeDuration": "00:19:09.5729600",
#   "effectiveStartTimeUtc": null,
#   "lastModifiedBy": {
#     "userObjectId": "d58acee8-35d9-4a26-9c33-6fc6220d8779",
#     "userPuId": "10032001A71563D6",
#     "userIdp": "live.com",
#     "userAltSecId": "1:live.com:00037FFE02800449",
#     "userIss": "https://sts.windows.net/3b230bda-fd85-4c71-87b7-bb8a2e9bbe9f/",
#     "userTenantId": "3b230bda-fd85-4c71-87b7-bb8a2e9bbe9f",
#     "userName": "albert wibowo",
#     "upn": null
#   },
#   "lastModifiedUtc": "2021-11-13T15:40:58.4696451+00:00",
#   "duration": "00:19:09.5729600",
#   "cancelationReason": null,
#   "runId": "HD_086c738f-33d5-484a-9596-021900feab2f",
#   "parentRunId": null,
#   "experimentId": "dd8f2ef1-dd49-4788-a859-e63ac140baea",
#   "status": "Completed",
#   "startTimeUtc": "2021-11-13T15:21:48.940263+00:00",
#   "endTimeUtc": "2021-11-13T15:40:58.513223+00:00",
#   "options": {
#     "generateDataContainerIdIfNotSpecified": true
#   },
#   "isVirtual": false,
#   "displayName": "silly_guava_ywp1gvmd",
#   "name": "azureml-capstone",
#   "dataContainerId": "dcid.HD_086c738f-33d5-484a-9596-021900feab2f",
#   "description": null,
#   "hidden": false,
#   "runType": "hyperdrive",
#   "runTypeV2": {
#     "orchestrator": "HyperDrive",
#     "traits": [
#       "hyperdrive",
#       "cpu-cluster"
#     ],
#     "attribution": null,
#     "computeType": null
#   },
#   "properties": {
#     "primary_metric_config": "{\"name\": \"AUC_weighted\", \"goal\": \"maximize\"}",
#     "resume_from": "null",
#     "runTemplate": "HyperDrive",
#     "azureml.runsource": "hyperdrive",
#     "platform": "AML",
#     "ContentSnapshotId": "ed2522a3-85e8-4431-a2ed-420333ff747a",
#     "user_agent": "python/3.6.9 (Linux-5.4.0-1056-azure-x86_64-with-debian-buster-sid) msrest/0.6.21 Hyperdrive.Service/1.0.0 Hyperdrive.SDK/core.1.34.0",
#     "score": "0.7774262768028579",
#     "best_child_run_id": "HD_086c738f-33d5-484a-9596-021900feab2f_7",
#     "best_metric_status": "Succeeded"
#   },
#   "parameters": {},
#   "actionUris": {
#     "Cancel": "https://westeurope.experiments.azureml.net/hyperdrive/v1.0/subscriptions/9d6e9855-22d9-4bd1-9b10-1f48fc786ab7/resourceGroups/udacity_capstone/providers/Microsoft.MachineLearningServices/workspaces/udacitycapstone/experiments/azureml-capstone/runs/HD_086c738f-33d5-484a-9596-021900feab2f/cancel"
#   },
#   "scriptName": "train.py",
#   "target": "cpu-cluster",
#   "uniqueChildRunComputeTargets": [],
#   "tags": {
#     "_aml_system_max_concurrent_jobs": "4",
#     "_aml_system_max_total_jobs": "12",
#     "_aml_system_max_duration_minutes": "10080",
#     "_aml_system_policy_config": "{\"name\": \"BANDIT\", \"properties\": {\"evaluation_interval\": 1, \"delay_evaluation\": 10, \"slack_factor\": 0.15}}",
#     "_aml_system_generator_config": "{\"name\": \"RANDOM\", \"parameter_space\": {\"n_estimators\": [\"choice\", [[100, 200, 500]]], \"learning_rate\": [\"uniform\", [0.1, 1.0]], \"max_depth\": [\"choice\", [[1, 3, 5]]]}}",
#     "_aml_system_primary_metric_config": "{\"name\": \"AUC_weighted\", \"goal\": \"maximize\"}",
#     "_aml_system_platform_config": "{\"ServiceAddress\": \"https://westeurope.experiments.azureml.net\", \"ServiceArmScope\": \"subscriptions/9d6e9855-22d9-4bd1-9b10-1f48fc786ab7/resourceGroups/udacity_capstone/providers/Microsoft.MachineLearningServices/workspaces/udacitycapstone/experiments/azureml-capstone\", \"SubscriptionId\": \"9d6e9855-22d9-4bd1-9b10-1f48fc786ab7\", \"ResourceGroupName\": \"udacity_capstone\", \"WorkspaceName\": \"udacitycapstone\", \"ExperimentName\": \"azureml-capstone\", \"Definition\": {\"Overrides\": {\"script\": \"train.py\", \"arguments\": [], \"target\": \"cpu-cluster\", \"framework\": \"Python\", \"communicator\": \"None\", \"maxRunDurationSeconds\": 2592000, \"nodeCount\": 1, \"priority\": null, \"environment\": {\"name\": \"sklearn-env\", \"version\": null, \"environmentVariables\": {\"EXAMPLE_ENV_VAR\": \"EXAMPLE_VALUE\"}, \"python\": {\"userManagedDependencies\": false, \"interpreterPath\": \"python\", \"condaDependenciesFile\": null, \"baseCondaEnvironment\": null, \"condaDependencies\": {\"dependencies\": [\"python=3.6.4\", \"scikit-learn\", \"pandas\", \"numpy\", {\"pip\": [\"azureml-defaults\"]}]}}, \"docker\": {\"enabled\": false, \"baseImage\": \"mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210806.v1\", \"baseDockerfile\": null, \"sharedVolumes\": true, \"shmSize\": \"2g\", \"arguments\": [], \"baseImageRegistry\": {\"address\": null, \"username\": null, \"password\": null, \"registryIdentity\": null}, \"platform\": {\"os\": \"Linux\", \"architecture\": \"amd64\"}}, \"spark\": {\"repositories\": [], \"packages\": [], \"precachePackages\": true}, \"databricks\": {\"mavenLibraries\": [], \"pypiLibraries\": [], \"rcranLibraries\": [], \"jarLibraries\": [], \"eggLibraries\": []}, \"r\": null, \"inferencingStackVersion\": null}, \"history\": {\"outputCollection\": true, \"snapshotProject\": true, \"directoriesToWatch\": [\"logs\"]}, \"spark\": {\"configuration\": {\"spark.app.name\": \"Azure ML Experiment\", \"spark.yarn.maxAppAttempts\": 1}}, \"docker\": {\"useDocker\": false, \"sharedVolumes\": true, \"arguments\": [], \"shmSize\": \"2g\"}, \"hdi\": {\"yarnDeployMode\": \"cluster\"}, \"tensorflow\": {\"workerCount\": 1, \"parameterServerCount\": 1}, \"mpi\": {\"processCountPerNode\": 1, \"nodeCount\": 1}, \"pytorch\": {\"communicationBackend\": \"nccl\", \"processCount\": null, \"nodeCount\": 1}, \"paralleltask\": {\"maxRetriesPerWorker\": 0, \"workerCountPerNode\": 1, \"terminalExitCodes\": null}, \"dataReferences\": {}, \"data\": {}, \"outputData\": {}, \"sourceDirectoryDataStore\": null, \"amlcompute\": {\"vmSize\": null, \"vmPriority\": null, \"retainCluster\": false, \"name\": null, \"clusterMaxNodeCount\": null}, \"credentialPassthrough\": false, \"command\": \"\", \"environmentVariables\": {}, \"applicationEndpoints\": {}}, \"TargetDetails\": null, \"SnapshotId\": \"ed2522a3-85e8-4431-a2ed-420333ff747a\", \"TelemetryValues\": {\"amlClientType\": \"azureml-sdk-train\", \"amlClientModule\": \"[Scrubbed]\", \"amlClientFunction\": \"[Scrubbed]\", \"tenantId\": \"3b230bda-fd85-4c71-87b7-bb8a2e9bbe9f\", \"amlClientRequestId\": \"0196667a-7807-42b5-b58f-df505b3345fd\", \"amlClientSessionId\": \"31df6067-7949-4077-acf2-97c30a607df7\", \"subscriptionId\": \"9d6e9855-22d9-4bd1-9b10-1f48fc786ab7\", \"estimator\": \"NoneType\", \"samplingMethod\": \"RANDOM\", \"terminationPolicy\": \"Bandit\", \"primaryMetricGoal\": \"maximize\", \"maxTotalRuns\": 12, \"maxConcurrentRuns\": 4, \"maxDurationMinutes\": 10080, \"vmSize\": null}}}",
#     "_aml_system_resume_child_runs": "null",
#     "_aml_system_all_jobs_generated": "true",
#     "_aml_system_cancellation_requested": "false",
#     "_aml_system_progress_metadata_evaluation_timestamp": "\"2021-11-13T15:21:49.996547\"",
#     "_aml_system_progress_metadata_digest": "\"7651dae33b8f777725621d6def7668859c1c96ccd1dd4fdaf5252924d657cf4a\"",
#     "_aml_system_progress_metadata_active_timestamp": "\"2021-11-13T15:21:49.996547\"",
#     "_aml_system_optimizer_state_artifact": "null",
#     "_aml_system_outdated_optimizer_state_artifacts": "\"[]\"",
#     "_aml_system_HD_086c738f-33d5-484a-9596-021900feab2f_0": "{\"learning_rate\": 0.8276933189270527, \"max_depth\": 3, \"n_estimators\": 500}",
#     "_aml_system_HD_086c738f-33d5-484a-9596-021900feab2f_1": "{\"learning_rate\": 0.27441530599983655, \"max_depth\": 3, \"n_estimators\": 100}",
#     "_aml_system_HD_086c738f-33d5-484a-9596-021900feab2f_2": "{\"learning_rate\": 0.4526540074952595, \"max_depth\": 1, \"n_estimators\": 500}",
#     "_aml_system_HD_086c738f-33d5-484a-9596-021900feab2f_3": "{\"learning_rate\": 0.5503538939190982, \"max_depth\": 5, \"n_estimators\": 100}",
#     "_aml_system_HD_086c738f-33d5-484a-9596-021900feab2f_4": "{\"learning_rate\": 0.4659393444884098, \"max_depth\": 5, \"n_estimators\": 200}",
#     "_aml_system_HD_086c738f-33d5-484a-9596-021900feab2f_5": "{\"learning_rate\": 0.8785206737631693, \"max_depth\": 5, \"n_estimators\": 100}",
#     "_aml_system_HD_086c738f-33d5-484a-9596-021900feab2f_6": "{\"learning_rate\": 0.753511194278563, \"max_depth\": 1, \"n_estimators\": 200}",
#     "_aml_system_HD_086c738f-33d5-484a-9596-021900feab2f_7": "{\"learning_rate\": 0.1429903627672755, \"max_depth\": 1, \"n_estimators\": 500}",
#     "_aml_system_HD_086c738f-33d5-484a-9596-021900feab2f_8": "{\"learning_rate\": 0.33597618464728807, \"max_depth\": 5, \"n_estimators\": 100}",
#     "_aml_system_HD_086c738f-33d5-484a-9596-021900feab2f_9": "{\"learning_rate\": 0.6878973252317377, \"max_depth\": 5, \"n_estimators\": 100}",
#     "_aml_system_HD_086c738f-33d5-484a-9596-021900feab2f_10": "{\"learning_rate\": 0.2350423025167096, \"max_depth\": 5, \"n_estimators\": 500}",
#     "_aml_system_HD_086c738f-33d5-484a-9596-021900feab2f_11": "{\"learning_rate\": 0.23891336343867833, \"max_depth\": 5, \"n_estimators\": 200}"
#   },
#   "settings": {},
#   "services": {},
#   "inputDatasets": [],
#   "outputDatasets": [],
#   "runDefinition": null,
#   "jobSpecification": null,
#   "primaryMetricName": "AUC_weighted",
#   "createdFrom": null,
#   "cancelUri": "https://westeurope.experiments.azureml.net/hyperdrive/v1.0/subscriptions/9d6e9855-22d9-4bd1-9b10-1f48fc786ab7/resourceGroups/udacity_capstone/providers/Microsoft.MachineLearningServices/workspaces/udacitycapstone/experiments/azureml-capstone/runs/HD_086c738f-33d5-484a-9596-021900feab2f/cancel",
#   "completeUri": null,
#   "diagnosticsUri": null,
#   "computeRequest": null,
#   "compute": null,
#   "retainForLifetimeOfWorkspace": false,
#   "queueingInfo": null,
#   "activeChildRunId": null
# }
# DEBUG:azureml.HyperDriveRun#HD_086c738f-33d5-484a-9596-021900feab2f.RunHistoryFacade.RunClient.get-async:False:[STOP]
# DEBUG:azureml.HyperDriveRun#HD_086c738f-33d5-484a-9596-021900feab2f.RunHistoryFacade.RunClient.get-async:False:[START]
# DEBUG:azureml.HyperDriveRun#HD_086c738f-33d5-484a-9596-021900feab2f.RunHistoryFacade.RunClient:ClientBase: Calling get with url /history/v1.0/subscriptions/{subscriptionId}/resourceGroups/{resourceGroupName}/providers/Microsoft.MachineLearningServices/workspaces/{workspaceName}/experiments/{experimentName}/runs/{runId}
# DEBUG:msrest.service_client:Accept header absent and forced to application/json
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): 127.0.1.1:46808
# DEBUG:urllib3.connectionpool:http://127.0.1.1:46808 "GET /MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01 HTTP/1.1" 200 2018
# DEBUG:msrestazure.azure_active_directory:MSI: Retrieving a token from http://127.0.1.1:46808/MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01
# DEBUG:msrestazure.azure_active_directory:MSI: token retrieved
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): 127.0.1.1:46808
# DEBUG:urllib3.connectionpool:http://127.0.1.1:46808 "GET /MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01 HTTP/1.1" 200 2018
# DEBUG:msrestazure.azure_active_directory:MSI: Retrieving a token from http://127.0.1.1:46808/MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01
# DEBUG:msrestazure.azure_active_directory:MSI: token retrieved
# DEBUG:msrest.http_logger:Request URL: 'https://westeurope.experiments.azureml.net/history/v1.0/subscriptions/9d6e9855-22d9-4bd1-9b10-1f48fc786ab7/resourceGroups/udacity_capstone/providers/Microsoft.MachineLearningServices/workspaces/udacitycapstone/experiments/azureml-capstone/runs/HD_086c738f-33d5-484a-9596-021900feab2f'
# DEBUG:msrest.http_logger:Request method: 'GET'
# DEBUG:msrest.http_logger:Request headers:
# DEBUG:msrest.http_logger:    'Accept': 'application/json'
# DEBUG:msrest.http_logger:    'Content-Type': 'application/json; charset=utf-8'
# DEBUG:msrest.http_logger:    'x-ms-client-request-id': '40d96523-baa8-4c83-a8df-2913686591b7'
# DEBUG:msrest.http_logger:    'request-id': '40d96523-baa8-4c83-a8df-2913686591b7'
# DEBUG:msrest.http_logger:    'User-Agent': 'python/3.6.9 (Linux-5.4.0-1056-azure-x86_64-with-debian-buster-sid) msrest/0.6.21 azureml._restclient/core.1.34.0 DSVM_workstation/47506801_21.09.20 azureml-sdk-core/1.34.0'
# DEBUG:msrest.http_logger:Request body:
# DEBUG:msrest.http_logger:None
# DEBUG:msrest.universal_http:Configuring redirects: allow=True, max=30
# DEBUG:msrest.universal_http:Configuring request: timeout=100, verify=True, cert=None
# DEBUG:msrest.universal_http:Configuring proxies: ''
# DEBUG:msrest.universal_http:Evaluate proxies against ENV settings: True
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): westeurope.experiments.azureml.net:443
# DEBUG:urllib3.connectionpool:https://westeurope.experiments.azureml.net:443 "GET /history/v1.0/subscriptions/9d6e9855-22d9-4bd1-9b10-1f48fc786ab7/resourceGroups/udacity_capstone/providers/Microsoft.MachineLearningServices/workspaces/udacitycapstone/experiments/azureml-capstone/runs/HD_086c738f-33d5-484a-9596-021900feab2f HTTP/1.1" 200 None
# DEBUG:msrest.http_logger:Response status: 200
# DEBUG:msrest.http_logger:Response headers:
# DEBUG:msrest.http_logger:    'Date': 'Sat, 13 Nov 2021 16:44:54 GMT'
# DEBUG:msrest.http_logger:    'Content-Type': 'application/json; charset=utf-8'
# DEBUG:msrest.http_logger:    'Transfer-Encoding': 'chunked'
# DEBUG:msrest.http_logger:    'Connection': 'keep-alive'
# DEBUG:msrest.http_logger:    'Vary': 'Accept-Encoding'
# DEBUG:msrest.http_logger:    'Request-Context': 'appId=cid-v1:6a27ce65-5555-41a3-85f7-b7a1ce31fd6b'
# DEBUG:msrest.http_logger:    'x-ms-response-type': 'standard'
# DEBUG:msrest.http_logger:    'Strict-Transport-Security': 'max-age=15724800; includeSubDomains; preload'
# DEBUG:msrest.http_logger:    'X-Content-Type-Options': 'nosniff'
# DEBUG:msrest.http_logger:    'x-request-time': '0.047'
# DEBUG:msrest.http_logger:    'Content-Encoding': 'gzip'
# DEBUG:msrest.http_logger:Response content:
# DEBUG:msrest.http_logger:{
#   "runNumber": 37,
#   "rootRunId": "HD_086c738f-33d5-484a-9596-021900feab2f",
#   "createdUtc": "2021-11-13T15:21:48.8529293+00:00",
#   "createdBy": {
#     "userObjectId": "d58acee8-35d9-4a26-9c33-6fc6220d8779",
#     "userPuId": "10032001A71563D6",
#     "userIdp": "live.com",
#     "userAltSecId": "1:live.com:00037FFE02800449",
#     "userIss": "https://sts.windows.net/3b230bda-fd85-4c71-87b7-bb8a2e9bbe9f/",
#     "userTenantId": "3b230bda-fd85-4c71-87b7-bb8a2e9bbe9f",
#     "userName": "albert wibowo",
#     "upn": null
#   },
#   "userId": "d58acee8-35d9-4a26-9c33-6fc6220d8779",
#   "token": null,
#   "tokenExpiryTimeUtc": null,
#   "error": null,
#   "warnings": null,
#   "revision": 18,
#   "statusRevision": 0,
#   "runUuid": "260cc845-74d2-47eb-b8d7-113f12619075",
#   "parentRunUuid": null,
#   "rootRunUuid": "260cc845-74d2-47eb-b8d7-113f12619075",
#   "hasVirtualParent": false,
#   "lastStartTimeUtc": null,
#   "currentComputeTime": null,
#   "computeDuration": "00:19:09.5729600",
#   "effectiveStartTimeUtc": null,
#   "lastModifiedBy": {
#     "userObjectId": "d58acee8-35d9-4a26-9c33-6fc6220d8779",
#     "userPuId": "10032001A71563D6",
#     "userIdp": "live.com",
#     "userAltSecId": "1:live.com:00037FFE02800449",
#     "userIss": "https://sts.windows.net/3b230bda-fd85-4c71-87b7-bb8a2e9bbe9f/",
#     "userTenantId": "3b230bda-fd85-4c71-87b7-bb8a2e9bbe9f",
#     "userName": "albert wibowo",
#     "upn": null
#   },
#   "lastModifiedUtc": "2021-11-13T15:40:58.4696451+00:00",
#   "duration": "00:19:09.5729600",
#   "cancelationReason": null,
#   "runId": "HD_086c738f-33d5-484a-9596-021900feab2f",
#   "parentRunId": null,
#   "experimentId": "dd8f2ef1-dd49-4788-a859-e63ac140baea",
#   "status": "Completed",
#   "startTimeUtc": "2021-11-13T15:21:48.940263+00:00",
#   "endTimeUtc": "2021-11-13T15:40:58.513223+00:00",
#   "options": {
#     "generateDataContainerIdIfNotSpecified": true
#   },
#   "isVirtual": false,
#   "displayName": "silly_guava_ywp1gvmd",
#   "name": "azureml-capstone",
#   "dataContainerId": "dcid.HD_086c738f-33d5-484a-9596-021900feab2f",
#   "description": null,
#   "hidden": false,
#   "runType": "hyperdrive",
#   "runTypeV2": {
#     "orchestrator": "HyperDrive",
#     "traits": [
#       "hyperdrive",
#       "cpu-cluster"
#     ],
#     "attribution": null,
#     "computeType": null
#   },
#   "properties": {
#     "primary_metric_config": "{\"name\": \"AUC_weighted\", \"goal\": \"maximize\"}",
#     "resume_from": "null",
#     "runTemplate": "HyperDrive",
#     "azureml.runsource": "hyperdrive",
#     "platform": "AML",
#     "ContentSnapshotId": "ed2522a3-85e8-4431-a2ed-420333ff747a",
#     "user_agent": "python/3.6.9 (Linux-5.4.0-1056-azure-x86_64-with-debian-buster-sid) msrest/0.6.21 Hyperdrive.Service/1.0.0 Hyperdrive.SDK/core.1.34.0",
#     "score": "0.7774262768028579",
#     "best_child_run_id": "HD_086c738f-33d5-484a-9596-021900feab2f_7",
#     "best_metric_status": "Succeeded"
#   },
#   "parameters": {},
#   "actionUris": {
#     "Cancel": "https://westeurope.experiments.azureml.net/hyperdrive/v1.0/subscriptions/9d6e9855-22d9-4bd1-9b10-1f48fc786ab7/resourceGroups/udacity_capstone/providers/Microsoft.MachineLearningServices/workspaces/udacitycapstone/experiments/azureml-capstone/runs/HD_086c738f-33d5-484a-9596-021900feab2f/cancel"
#   },
#   "scriptName": "train.py",
#   "target": "cpu-cluster",
#   "uniqueChildRunComputeTargets": [],
#   "tags": {
#     "_aml_system_max_concurrent_jobs": "4",
#     "_aml_system_max_total_jobs": "12",
#     "_aml_system_max_duration_minutes": "10080",
#     "_aml_system_policy_config": "{\"name\": \"BANDIT\", \"properties\": {\"evaluation_interval\": 1, \"delay_evaluation\": 10, \"slack_factor\": 0.15}}",
#     "_aml_system_generator_config": "{\"name\": \"RANDOM\", \"parameter_space\": {\"n_estimators\": [\"choice\", [[100, 200, 500]]], \"learning_rate\": [\"uniform\", [0.1, 1.0]], \"max_depth\": [\"choice\", [[1, 3, 5]]]}}",
#     "_aml_system_primary_metric_config": "{\"name\": \"AUC_weighted\", \"goal\": \"maximize\"}",
#     "_aml_system_platform_config": "{\"ServiceAddress\": \"https://westeurope.experiments.azureml.net\", \"ServiceArmScope\": \"subscriptions/9d6e9855-22d9-4bd1-9b10-1f48fc786ab7/resourceGroups/udacity_capstone/providers/Microsoft.MachineLearningServices/workspaces/udacitycapstone/experiments/azureml-capstone\", \"SubscriptionId\": \"9d6e9855-22d9-4bd1-9b10-1f48fc786ab7\", \"ResourceGroupName\": \"udacity_capstone\", \"WorkspaceName\": \"udacitycapstone\", \"ExperimentName\": \"azureml-capstone\", \"Definition\": {\"Overrides\": {\"script\": \"train.py\", \"arguments\": [], \"target\": \"cpu-cluster\", \"framework\": \"Python\", \"communicator\": \"None\", \"maxRunDurationSeconds\": 2592000, \"nodeCount\": 1, \"priority\": null, \"environment\": {\"name\": \"sklearn-env\", \"version\": null, \"environmentVariables\": {\"EXAMPLE_ENV_VAR\": \"EXAMPLE_VALUE\"}, \"python\": {\"userManagedDependencies\": false, \"interpreterPath\": \"python\", \"condaDependenciesFile\": null, \"baseCondaEnvironment\": null, \"condaDependencies\": {\"dependencies\": [\"python=3.6.4\", \"scikit-learn\", \"pandas\", \"numpy\", {\"pip\": [\"azureml-defaults\"]}]}}, \"docker\": {\"enabled\": false, \"baseImage\": \"mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210806.v1\", \"baseDockerfile\": null, \"sharedVolumes\": true, \"shmSize\": \"2g\", \"arguments\": [], \"baseImageRegistry\": {\"address\": null, \"username\": null, \"password\": null, \"registryIdentity\": null}, \"platform\": {\"os\": \"Linux\", \"architecture\": \"amd64\"}}, \"spark\": {\"repositories\": [], \"packages\": [], \"precachePackages\": true}, \"databricks\": {\"mavenLibraries\": [], \"pypiLibraries\": [], \"rcranLibraries\": [], \"jarLibraries\": [], \"eggLibraries\": []}, \"r\": null, \"inferencingStackVersion\": null}, \"history\": {\"outputCollection\": true, \"snapshotProject\": true, \"directoriesToWatch\": [\"logs\"]}, \"spark\": {\"configuration\": {\"spark.app.name\": \"Azure ML Experiment\", \"spark.yarn.maxAppAttempts\": 1}}, \"docker\": {\"useDocker\": false, \"sharedVolumes\": true, \"arguments\": [], \"shmSize\": \"2g\"}, \"hdi\": {\"yarnDeployMode\": \"cluster\"}, \"tensorflow\": {\"workerCount\": 1, \"parameterServerCount\": 1}, \"mpi\": {\"processCountPerNode\": 1, \"nodeCount\": 1}, \"pytorch\": {\"communicationBackend\": \"nccl\", \"processCount\": null, \"nodeCount\": 1}, \"paralleltask\": {\"maxRetriesPerWorker\": 0, \"workerCountPerNode\": 1, \"terminalExitCodes\": null}, \"dataReferences\": {}, \"data\": {}, \"outputData\": {}, \"sourceDirectoryDataStore\": null, \"amlcompute\": {\"vmSize\": null, \"vmPriority\": null, \"retainCluster\": false, \"name\": null, \"clusterMaxNodeCount\": null}, \"credentialPassthrough\": false, \"command\": \"\", \"environmentVariables\": {}, \"applicationEndpoints\": {}}, \"TargetDetails\": null, \"SnapshotId\": \"ed2522a3-85e8-4431-a2ed-420333ff747a\", \"TelemetryValues\": {\"amlClientType\": \"azureml-sdk-train\", \"amlClientModule\": \"[Scrubbed]\", \"amlClientFunction\": \"[Scrubbed]\", \"tenantId\": \"3b230bda-fd85-4c71-87b7-bb8a2e9bbe9f\", \"amlClientRequestId\": \"0196667a-7807-42b5-b58f-df505b3345fd\", \"amlClientSessionId\": \"31df6067-7949-4077-acf2-97c30a607df7\", \"subscriptionId\": \"9d6e9855-22d9-4bd1-9b10-1f48fc786ab7\", \"estimator\": \"NoneType\", \"samplingMethod\": \"RANDOM\", \"terminationPolicy\": \"Bandit\", \"primaryMetricGoal\": \"maximize\", \"maxTotalRuns\": 12, \"maxConcurrentRuns\": 4, \"maxDurationMinutes\": 10080, \"vmSize\": null}}}",
#     "_aml_system_resume_child_runs": "null",
#     "_aml_system_all_jobs_generated": "true",
#     "_aml_system_cancellation_requested": "false",
#     "_aml_system_progress_metadata_evaluation_timestamp": "\"2021-11-13T15:21:49.996547\"",
#     "_aml_system_progress_metadata_digest": "\"7651dae33b8f777725621d6def7668859c1c96ccd1dd4fdaf5252924d657cf4a\"",
#     "_aml_system_progress_metadata_active_timestamp": "\"2021-11-13T15:21:49.996547\"",
#     "_aml_system_optimizer_state_artifact": "null",
#     "_aml_system_outdated_optimizer_state_artifacts": "\"[]\"",
#     "_aml_system_HD_086c738f-33d5-484a-9596-021900feab2f_0": "{\"learning_rate\": 0.8276933189270527, \"max_depth\": 3, \"n_estimators\": 500}",
#     "_aml_system_HD_086c738f-33d5-484a-9596-021900feab2f_1": "{\"learning_rate\": 0.27441530599983655, \"max_depth\": 3, \"n_estimators\": 100}",
#     "_aml_system_HD_086c738f-33d5-484a-9596-021900feab2f_2": "{\"learning_rate\": 0.4526540074952595, \"max_depth\": 1, \"n_estimators\": 500}",
#     "_aml_system_HD_086c738f-33d5-484a-9596-021900feab2f_3": "{\"learning_rate\": 0.5503538939190982, \"max_depth\": 5, \"n_estimators\": 100}",
#     "_aml_system_HD_086c738f-33d5-484a-9596-021900feab2f_4": "{\"learning_rate\": 0.4659393444884098, \"max_depth\": 5, \"n_estimators\": 200}",
#     "_aml_system_HD_086c738f-33d5-484a-9596-021900feab2f_5": "{\"learning_rate\": 0.8785206737631693, \"max_depth\": 5, \"n_estimators\": 100}",
#     "_aml_system_HD_086c738f-33d5-484a-9596-021900feab2f_6": "{\"learning_rate\": 0.753511194278563, \"max_depth\": 1, \"n_estimators\": 200}",
#     "_aml_system_HD_086c738f-33d5-484a-9596-021900feab2f_7": "{\"learning_rate\": 0.1429903627672755, \"max_depth\": 1, \"n_estimators\": 500}",
#     "_aml_system_HD_086c738f-33d5-484a-9596-021900feab2f_8": "{\"learning_rate\": 0.33597618464728807, \"max_depth\": 5, \"n_estimators\": 100}",
#     "_aml_system_HD_086c738f-33d5-484a-9596-021900feab2f_9": "{\"learning_rate\": 0.6878973252317377, \"max_depth\": 5, \"n_estimators\": 100}",
#     "_aml_system_HD_086c738f-33d5-484a-9596-021900feab2f_10": "{\"learning_rate\": 0.2350423025167096, \"max_depth\": 5, \"n_estimators\": 500}",
#     "_aml_system_HD_086c738f-33d5-484a-9596-021900feab2f_11": "{\"learning_rate\": 0.23891336343867833, \"max_depth\": 5, \"n_estimators\": 200}"
#   },
#   "settings": {},
#   "services": {},
#   "inputDatasets": [],
#   "outputDatasets": [],
#   "runDefinition": null,
#   "jobSpecification": null,
#   "primaryMetricName": "AUC_weighted",
#   "createdFrom": null,
#   "cancelUri": "https://westeurope.experiments.azureml.net/hyperdrive/v1.0/subscriptions/9d6e9855-22d9-4bd1-9b10-1f48fc786ab7/resourceGroups/udacity_capstone/providers/Microsoft.MachineLearningServices/workspaces/udacitycapstone/experiments/azureml-capstone/runs/HD_086c738f-33d5-484a-9596-021900feab2f/cancel",
#   "completeUri": null,
#   "diagnosticsUri": null,
#   "computeRequest": null,
#   "compute": null,
#   "retainForLifetimeOfWorkspace": false,
#   "queueingInfo": null,
#   "activeChildRunId": null
# }
# DEBUG:azureml.HyperDriveRun#HD_086c738f-33d5-484a-9596-021900feab2f.RunHistoryFacade.RunClient.get-async:False:[STOP]
# DEBUG:azureml.HyperDriveRun#HD_086c738f-33d5-484a-9596-021900feab2f.RunHistoryFacade.RunClient.get-async:False:[START]
# DEBUG:azureml.HyperDriveRun#HD_086c738f-33d5-484a-9596-021900feab2f.RunHistoryFacade.RunClient:ClientBase: Calling get with url /history/v1.0/subscriptions/{subscriptionId}/resourceGroups/{resourceGroupName}/providers/Microsoft.MachineLearningServices/workspaces/{workspaceName}/experiments/{experimentName}/runs/{runId}
# DEBUG:msrest.service_client:Accept header absent and forced to application/json
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): 127.0.1.1:46808
# DEBUG:urllib3.connectionpool:http://127.0.1.1:46808 "GET /MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01 HTTP/1.1" 200 2018
# DEBUG:msrestazure.azure_active_directory:MSI: Retrieving a token from http://127.0.1.1:46808/MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01
# DEBUG:msrestazure.azure_active_directory:MSI: token retrieved
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): 127.0.1.1:46808
# DEBUG:urllib3.connectionpool:http://127.0.1.1:46808 "GET /MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01 HTTP/1.1" 200 2018
# DEBUG:msrestazure.azure_active_directory:MSI: Retrieving a token from http://127.0.1.1:46808/MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01
# DEBUG:msrestazure.azure_active_directory:MSI: token retrieved
# DEBUG:msrest.http_logger:Request URL: 'https://westeurope.experiments.azureml.net/history/v1.0/subscriptions/9d6e9855-22d9-4bd1-9b10-1f48fc786ab7/resourceGroups/udacity_capstone/providers/Microsoft.MachineLearningServices/workspaces/udacitycapstone/experiments/azureml-capstone/runs/HD_086c738f-33d5-484a-9596-021900feab2f'
# DEBUG:msrest.http_logger:Request method: 'GET'
# DEBUG:msrest.http_logger:Request headers:
# DEBUG:msrest.http_logger:    'Accept': 'application/json'
# DEBUG:msrest.http_logger:    'Content-Type': 'application/json; charset=utf-8'
# DEBUG:msrest.http_logger:    'x-ms-client-request-id': '4e67d03c-3a3c-48e3-9d5f-099b66902123'
# DEBUG:msrest.http_logger:    'request-id': '4e67d03c-3a3c-48e3-9d5f-099b66902123'
# DEBUG:msrest.http_logger:    'User-Agent': 'python/3.6.9 (Linux-5.4.0-1056-azure-x86_64-with-debian-buster-sid) msrest/0.6.21 azureml._restclient/core.1.34.0 DSVM_workstation/47506801_21.09.20 azureml-sdk-core/1.34.0'
# DEBUG:msrest.http_logger:Request body:
# DEBUG:msrest.http_logger:None
# DEBUG:msrest.universal_http:Configuring redirects: allow=True, max=30
# DEBUG:msrest.universal_http:Configuring request: timeout=100, verify=True, cert=None
# DEBUG:msrest.universal_http:Configuring proxies: ''
# DEBUG:msrest.universal_http:Evaluate proxies against ENV settings: True
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): westeurope.experiments.azureml.net:443
# DEBUG:urllib3.connectionpool:https://westeurope.experiments.azureml.net:443 "GET /history/v1.0/subscriptions/9d6e9855-22d9-4bd1-9b10-1f48fc786ab7/resourceGroups/udacity_capstone/providers/Microsoft.MachineLearningServices/workspaces/udacitycapstone/experiments/azureml-capstone/runs/HD_086c738f-33d5-484a-9596-021900feab2f HTTP/1.1" 200 None
# DEBUG:msrest.http_logger:Response status: 200
# DEBUG:msrest.http_logger:Response headers:
# DEBUG:msrest.http_logger:    'Date': 'Sat, 13 Nov 2021 16:44:54 GMT'
# DEBUG:msrest.http_logger:    'Content-Type': 'application/json; charset=utf-8'
# DEBUG:msrest.http_logger:    'Transfer-Encoding': 'chunked'
# DEBUG:msrest.http_logger:    'Connection': 'keep-alive'
# DEBUG:msrest.http_logger:    'Vary': 'Accept-Encoding'
# DEBUG:msrest.http_logger:    'Request-Context': 'appId=cid-v1:6a27ce65-5555-41a3-85f7-b7a1ce31fd6b'
# DEBUG:msrest.http_logger:    'x-ms-response-type': 'standard'
# DEBUG:msrest.http_logger:    'Strict-Transport-Security': 'max-age=15724800; includeSubDomains; preload'
# DEBUG:msrest.http_logger:    'X-Content-Type-Options': 'nosniff'
# DEBUG:msrest.http_logger:    'x-request-time': '0.042'
# DEBUG:msrest.http_logger:    'Content-Encoding': 'gzip'
# DEBUG:msrest.http_logger:Response content:
# DEBUG:msrest.http_logger:{
#   "runNumber": 37,
#   "rootRunId": "HD_086c738f-33d5-484a-9596-021900feab2f",
#   "createdUtc": "2021-11-13T15:21:48.8529293+00:00",
#   "createdBy": {
#     "userObjectId": "d58acee8-35d9-4a26-9c33-6fc6220d8779",
#     "userPuId": "10032001A71563D6",
#     "userIdp": "live.com",
#     "userAltSecId": "1:live.com:00037FFE02800449",
#     "userIss": "https://sts.windows.net/3b230bda-fd85-4c71-87b7-bb8a2e9bbe9f/",
#     "userTenantId": "3b230bda-fd85-4c71-87b7-bb8a2e9bbe9f",
#     "userName": "albert wibowo",
#     "upn": null
#   },
#   "userId": "d58acee8-35d9-4a26-9c33-6fc6220d8779",
#   "token": null,
#   "tokenExpiryTimeUtc": null,
#   "error": null,
#   "warnings": null,
#   "revision": 18,
#   "statusRevision": 0,
#   "runUuid": "260cc845-74d2-47eb-b8d7-113f12619075",
#   "parentRunUuid": null,
#   "rootRunUuid": "260cc845-74d2-47eb-b8d7-113f12619075",
#   "hasVirtualParent": false,
#   "lastStartTimeUtc": null,
#   "currentComputeTime": null,
# ...
# DEBUG:azureml.WorkspaceClient:ClientBase: Calling get with url /history/v1.0/subscriptions/{subscriptionId}/resourceGroups/{resourceGroupName}/providers/Microsoft.MachineLearningServices/workspaces/{workspaceName}/experiments/{experimentName}
# DEBUG:msrest.service_client:Accept header absent and forced to application/json
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): 127.0.1.1:46808
# DEBUG:urllib3.connectionpool:http://127.0.1.1:46808 "GET /MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01 HTTP/1.1" 200 2018
# DEBUG:msrestazure.azure_active_directory:MSI: Retrieving a token from http://127.0.1.1:46808/MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01
# DEBUG:msrestazure.azure_active_directory:MSI: token retrieved
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): 127.0.1.1:46808
# DEBUG:urllib3.connectionpool:http://127.0.1.1:46808 "GET /MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01 HTTP/1.1" 200 2018
# DEBUG:msrestazure.azure_active_directory:MSI: Retrieving a token from http://127.0.1.1:46808/MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01
# DEBUG:msrestazure.azure_active_directory:MSI: token retrieved
# DEBUG:msrest.http_logger:Request URL: 'https://westeurope.experiments.azureml.net/history/v1.0/subscriptions/9d6e9855-22d9-4bd1-9b10-1f48fc786ab7/resourceGroups/udacity_capstone/providers/Microsoft.MachineLearningServices/workspaces/udacitycapstone/experiments/azureml-capstone'
# DEBUG:msrest.http_logger:Request method: 'GET'
# DEBUG:msrest.http_logger:Request headers:
# DEBUG:msrest.http_logger:    'Accept': 'application/json'
# DEBUG:msrest.http_logger:    'Content-Type': 'application/json; charset=utf-8'
# DEBUG:msrest.http_logger:    'x-ms-client-request-id': '5a30d124-51f2-40cb-9312-255d3320cdb5'
# DEBUG:msrest.http_logger:    'request-id': '5a30d124-51f2-40cb-9312-255d3320cdb5'
# DEBUG:msrest.http_logger:    'User-Agent': 'python/3.6.9 (Linux-5.4.0-1056-azure-x86_64-with-debian-buster-sid) msrest/0.6.21 azureml._restclient/core.1.34.0 DSVM_workstation/47506801_21.09.20 azureml-sdk-core/1.34.0'
# DEBUG:msrest.http_logger:Request body:
# DEBUG:msrest.http_logger:None
# DEBUG:msrest.universal_http:Configuring redirects: allow=True, max=30
# DEBUG:msrest.universal_http:Configuring request: timeout=100, verify=True, cert=None
# DEBUG:msrest.universal_http:Configuring proxies: ''
# DEBUG:msrest.universal_http:Evaluate proxies against ENV settings: True
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): westeurope.experiments.azureml.net:443
# DEBUG:urllib3.connectionpool:https://westeurope.experiments.azureml.net:443 "GET /history/v1.0/subscriptions/9d6e9855-22d9-4bd1-9b10-1f48fc786ab7/resourceGroups/udacity_capstone/providers/Microsoft.MachineLearningServices/workspaces/udacitycapstone/experiments/azureml-capstone HTTP/1.1" 200 245
# DEBUG:msrest.http_logger:Response status: 200
# DEBUG:msrest.http_logger:Response headers:
# DEBUG:msrest.http_logger:    'Date': 'Sat, 13 Nov 2021 16:48:48 GMT'
# DEBUG:msrest.http_logger:    'Content-Type': 'application/json; charset=utf-8'
# DEBUG:msrest.http_logger:    'Content-Length': '245'
# DEBUG:msrest.http_logger:    'Connection': 'keep-alive'
# DEBUG:msrest.http_logger:    'Request-Context': 'appId=cid-v1:6a27ce65-5555-41a3-85f7-b7a1ce31fd6b'
# DEBUG:msrest.http_logger:    'x-ms-response-type': 'standard'
# DEBUG:msrest.http_logger:    'Strict-Transport-Security': 'max-age=15724800; includeSubDomains; preload'
# DEBUG:msrest.http_logger:    'X-Content-Type-Options': 'nosniff'
# DEBUG:msrest.http_logger:    'x-request-time': '0.038'
# DEBUG:msrest.http_logger:Response content:
# DEBUG:msrest.http_logger:{
#   "experimentId": "dd8f2ef1-dd49-4788-a859-e63ac140baea",
#   "name": "azureml-capstone",
#   "description": null,
#   "createdUtc": "2021-11-13T14:11:49.6135685+00:00",
#   "tags": {},
#   "archivedTime": null,
#   "retainForLifetimeOfWorkspace": false
# }
# DEBUG:azureml.WorkspaceClient.get-async:False:[STOP]
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): 127.0.1.1:46808
# DEBUG:urllib3.connectionpool:http://127.0.1.1:46808 "GET /MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01 HTTP/1.1" 200 2018
# DEBUG:msrestazure.azure_active_directory:MSI: Retrieving a token from http://127.0.1.1:46808/MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01
# DEBUG:msrestazure.azure_active_directory:MSI: token retrieved
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): 127.0.1.1:46808
# DEBUG:urllib3.connectionpool:http://127.0.1.1:46808 "GET /MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01 HTTP/1.1" 200 2018
# DEBUG:msrestazure.azure_active_directory:MSI: Retrieving a token from http://127.0.1.1:46808/MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01
# DEBUG:msrestazure.azure_active_directory:MSI: token retrieved
# DEBUG:azureml.RunClient.get_by_exp_id-async:False:[START]
# DEBUG:azureml.RunClient:ClientBase: Calling get_by_exp_id with url /history/v1.0/subscriptions/{subscriptionId}/resourceGroups/{resourceGroupName}/providers/Microsoft.MachineLearningServices/workspaces/{workspaceName}/experimentids/{experimentId}/runs/{runId}
# DEBUG:msrest.service_client:Accept header absent and forced to application/json
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): 127.0.1.1:46808
# DEBUG:urllib3.connectionpool:http://127.0.1.1:46808 "GET /MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01 HTTP/1.1" 200 2018
# DEBUG:msrestazure.azure_active_directory:MSI: Retrieving a token from http://127.0.1.1:46808/MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01
# DEBUG:msrestazure.azure_active_directory:MSI: token retrieved
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): 127.0.1.1:46808
# DEBUG:urllib3.connectionpool:http://127.0.1.1:46808 "GET /MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01 HTTP/1.1" 200 2018
# DEBUG:msrestazure.azure_active_directory:MSI: Retrieving a token from http://127.0.1.1:46808/MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01
# DEBUG:msrestazure.azure_active_directory:MSI: token retrieved
# DEBUG:msrest.http_logger:Request URL: 'https://westeurope.experiments.azureml.net/history/v1.0/subscriptions/9d6e9855-22d9-4bd1-9b10-1f48fc786ab7/resourceGroups/udacity_capstone/providers/Microsoft.MachineLearningServices/workspaces/udacitycapstone/experimentids/dd8f2ef1-dd49-4788-a859-e63ac140baea/runs/HD_086c738f-33d5-484a-9596-021900feab2f_7'
# DEBUG:msrest.http_logger:Request method: 'GET'
# DEBUG:msrest.http_logger:Request headers:
# DEBUG:msrest.http_logger:    'Accept': 'application/json'
# DEBUG:msrest.http_logger:    'Content-Type': 'application/json; charset=utf-8'
# DEBUG:msrest.http_logger:    'x-ms-client-request-id': 'da9a70c6-0ea5-40c5-b98b-e0b72e573f5e'
# DEBUG:msrest.http_logger:    'request-id': 'da9a70c6-0ea5-40c5-b98b-e0b72e573f5e'
# DEBUG:msrest.http_logger:    'User-Agent': 'python/3.6.9 (Linux-5.4.0-1056-azure-x86_64-with-debian-buster-sid) msrest/0.6.21 azureml._restclient/core.1.34.0 DSVM_workstation/47506801_21.09.20 azureml-sdk-core/1.34.0'
# DEBUG:msrest.http_logger:Request body:
# DEBUG:msrest.http_logger:None
# DEBUG:msrest.universal_http:Configuring redirects: allow=True, max=30
# DEBUG:msrest.universal_http:Configuring request: timeout=100, verify=True, cert=None
# DEBUG:msrest.universal_http:Configuring proxies: ''
# DEBUG:msrest.universal_http:Evaluate proxies against ENV settings: True
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): westeurope.experiments.azureml.net:443
# DEBUG:urllib3.connectionpool:https://westeurope.experiments.azureml.net:443 "GET /history/v1.0/subscriptions/9d6e9855-22d9-4bd1-9b10-1f48fc786ab7/resourceGroups/udacity_capstone/providers/Microsoft.MachineLearningServices/workspaces/udacitycapstone/experimentids/dd8f2ef1-dd49-4788-a859-e63ac140baea/runs/HD_086c738f-33d5-484a-9596-021900feab2f_7 HTTP/1.1" 200 None
# DEBUG:msrest.http_logger:Response status: 200
# DEBUG:msrest.http_logger:Response headers:
# DEBUG:msrest.http_logger:    'Date': 'Sat, 13 Nov 2021 16:48:48 GMT'
# DEBUG:msrest.http_logger:    'Content-Type': 'application/json; charset=utf-8'
# DEBUG:msrest.http_logger:    'Transfer-Encoding': 'chunked'
# DEBUG:msrest.http_logger:    'Connection': 'keep-alive'
# DEBUG:msrest.http_logger:    'Vary': 'Accept-Encoding'
# DEBUG:msrest.http_logger:    'Request-Context': 'appId=cid-v1:6a27ce65-5555-41a3-85f7-b7a1ce31fd6b'
# DEBUG:msrest.http_logger:    'x-ms-response-type': 'standard'
# DEBUG:msrest.http_logger:    'Strict-Transport-Security': 'max-age=15724800; includeSubDomains; preload'
# DEBUG:msrest.http_logger:    'X-Content-Type-Options': 'nosniff'
# DEBUG:msrest.http_logger:    'x-request-time': '0.040'
# DEBUG:msrest.http_logger:    'Content-Encoding': 'gzip'
# DEBUG:msrest.http_logger:Response content:
# DEBUG:msrest.http_logger:{
#   "runNumber": 45,
#   "rootRunId": "HD_086c738f-33d5-484a-9596-021900feab2f",
#   "createdUtc": "2021-11-13T15:29:25.4030427+00:00",
#   "createdBy": {
#     "userObjectId": "d58acee8-35d9-4a26-9c33-6fc6220d8779",
#     "userPuId": "10032001A71563D6",
#     "userIdp": "live.com",
#     "userAltSecId": "1:live.com:00037FFE02800449",
#     "userIss": "https://sts.windows.net/3b230bda-fd85-4c71-87b7-bb8a2e9bbe9f/",
#     "userTenantId": "3b230bda-fd85-4c71-87b7-bb8a2e9bbe9f",
#     "userName": "albert wibowo",
#     "upn": null
#   },
#   "userId": "d58acee8-35d9-4a26-9c33-6fc6220d8779",
#   "token": null,
#   "tokenExpiryTimeUtc": null,
#   "error": null,
#   "warnings": null,
#   "revision": 10,
#   "statusRevision": 2,
#   "runUuid": "e4c95e63-0023-4aad-bb27-3149130b9a74",
#   "parentRunUuid": "260cc845-74d2-47eb-b8d7-113f12619075",
#   "rootRunUuid": "260cc845-74d2-47eb-b8d7-113f12619075",
#   "hasVirtualParent": false,
#   "lastStartTimeUtc": null,
#   "currentComputeTime": null,
#   "computeDuration": "00:01:18.4768635",
#   "effectiveStartTimeUtc": null,
#   "lastModifiedBy": {
#     "userObjectId": "d58acee8-35d9-4a26-9c33-6fc6220d8779",
#     "userPuId": "10032001A71563D6",
#     "userIdp": "live.com",
#     "userAltSecId": "1:live.com:00037FFE02800449",
#     "userIss": "https://sts.windows.net/3b230bda-fd85-4c71-87b7-bb8a2e9bbe9f/",
#     "userTenantId": "3b230bda-fd85-4c71-87b7-bb8a2e9bbe9f",
#     "userName": "albert wibowo",
#     "upn": null
#   },
#   "lastModifiedUtc": "2021-11-13T15:29:28.3859351+00:00",
#   "duration": "00:01:18.4768635",
#   "cancelationReason": null,
#   "runId": "HD_086c738f-33d5-484a-9596-021900feab2f_7",
#   "parentRunId": "HD_086c738f-33d5-484a-9596-021900feab2f",
#   "experimentId": "dd8f2ef1-dd49-4788-a859-e63ac140baea",
#   "status": "Completed",
#   "startTimeUtc": "2021-11-13T15:33:58.1164966+00:00",
#   "endTimeUtc": "2021-11-13T15:35:16.5933601+00:00",
#   "options": {
#     "generateDataContainerIdIfNotSpecified": true
#   },
#   "isVirtual": false,
#   "displayName": "goofy_energy_kq6jqbhx",
#   "name": null,
#   "dataContainerId": "dcid.HD_086c738f-33d5-484a-9596-021900feab2f_7",
#   "description": null,
#   "hidden": false,
#   "runType": "azureml.scriptrun",
#   "runTypeV2": {
#     "orchestrator": "Execution",
#     "traits": [
#       "scriptRun",
#       "remote",
#       "Hosttools"
#     ],
#     "attribution": "HyperDrive",
#     "computeType": "AmlcTrain"
#   },
#   "properties": {
#     "_azureml.ComputeTargetType": "amlcompute",
#     "ContentSnapshotId": "ed2522a3-85e8-4431-a2ed-420333ff747a",
#     "ProcessInfoFile": "azureml-logs/process_info.json",
#     "ProcessStatusFile": "azureml-logs/process_status.json"
#   },
#   "parameters": {},
#   "actionUris": {
#     "Cancel": "https://westeurope.api.azureml.ms/execution/v1.0/subscriptions/9d6e9855-22d9-4bd1-9b10-1f48fc786ab7/resourceGroups/udacity_capstone/providers/Microsoft.MachineLearningServices/workspaces/udacitycapstone/experiments/azureml-capstone/runId/HD_086c738f-33d5-484a-9596-021900feab2f_7/cancel",
#     "Diagnose": ""
#   },
#   "scriptName": "train.py",
#   "target": "cpu-cluster",
#   "uniqueChildRunComputeTargets": [],
#   "tags": {
#     "_aml_system_hyperparameters": "{\"learning_rate\": 0.1429903627672755, \"max_depth\": 1, \"n_estimators\": 500}",
#     "hyperparameters": "{\"learning_rate\": 0.1429903627672755, \"max_depth\": 1, \"n_estimators\": 500}",
#     "_aml_system_ComputeTargetStatus": "{\"AllocationState\":\"steady\",\"PreparingNodeCount\":0,\"RunningNodeCount\":1,\"CurrentNodeCount\":1}"
#   },
#   "settings": {},
#   "services": {},
#   "inputDatasets": [],
#   "outputDatasets": [],
#   "runDefinition": null,
#   "jobSpecification": null,
#   "primaryMetricName": "AUC_weighted",
#   "createdFrom": null,
#   "cancelUri": "https://westeurope.api.azureml.ms/execution/v1.0/subscriptions/9d6e9855-22d9-4bd1-9b10-1f48fc786ab7/resourceGroups/udacity_capstone/providers/Microsoft.MachineLearningServices/workspaces/udacitycapstone/experiments/azureml-capstone/runId/HD_086c738f-33d5-484a-9596-021900feab2f_7/cancel",
#   "completeUri": null,
#   "diagnosticsUri": "",
#   "computeRequest": {
#     "nodeCount": 1,
#     "gpuCount": 0
#   },
#   "compute": null,
#   "retainForLifetimeOfWorkspace": null,
#   "queueingInfo": null,
#   "activeChildRunId": null
# }
# DEBUG:azureml.RunClient.get_by_exp_id-async:False:[STOP]
# DEBUG:azureml.core.run:Available factories for run types {'hyperdrive': <function HyperDriveRun._from_run_dto at 0x7fdf5d070a60>, 'automl': <function AutoMLRun._from_run_dto at 0x7fdf5c7e8840>, 'azureml.PipelineRun': <function PipelineRun._from_dto at 0x7fdf5ccff6a8>, 'azureml.ReusedStepRun': <function StepRun._from_reused_dto at 0x7fdf5cd00158>, 'azureml.StepRun': <function StepRun._from_dto at 0x7fdf5cd000d0>, 'azureml.scriptrun': <function ScriptRun._from_run_dto at 0x7fdf5d232d08>}
# DEBUG:azureml.core.run:Initializing Run HD_086c738f-33d5-484a-9596-021900feab2f_7 from type azureml.scriptrun
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): 127.0.1.1:46808
# DEBUG:urllib3.connectionpool:http://127.0.1.1:46808 "GET /MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01 HTTP/1.1" 200 2018
# DEBUG:msrestazure.azure_active_directory:MSI: Retrieving a token from http://127.0.1.1:46808/MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01
# DEBUG:msrestazure.azure_active_directory:MSI: token retrieved
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): 127.0.1.1:46808
# DEBUG:urllib3.connectionpool:http://127.0.1.1:46808 "GET /MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01 HTTP/1.1" 200 2018
# DEBUG:msrestazure.azure_active_directory:MSI: Retrieving a token from http://127.0.1.1:46808/MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01
# DEBUG:msrestazure.azure_active_directory:MSI: token retrieved
# DEBUG:azureml.ScriptRun#HD_086c738f-33d5-484a-9596-021900feab2f_7:Constructing run from dto. type: azureml.scriptrun, source: None, props: {'_azureml.ComputeTargetType': 'amlcompute', 'ContentSnapshotId': 'ed2522a3-85e8-4431-a2ed-420333ff747a', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}
# DEBUG:azureml.ScriptRun#HD_086c738f-33d5-484a-9596-021900feab2f_7.RunContextManager:Valid logs dir, setting up content loader
# Tips: You can try get_logs(): https://aka.ms/debugimage#dockerlog or local deployment: https://aka.ms/debugimage#debug-locally to debug if deployment takes longer than 10 minutes.
# Running
# 2021-11-13 16:45:34+00:00 Creating Container Registry if not exists.
# 2021-11-13 16:45:34+00:00 Registering the environment.
# 2021-11-13 16:45:34+00:00 Use the existing image.
# 2021-11-13 16:45:34+00:00 Generating deployment configuration.
# 2021-11-13 16:45:38+00:00 Submitting deployment to compute.
# 2021-11-13 16:45:43+00:00 Checking the status of deployment credit-hyper-service..
# 2021-11-13 16:47:57+00:00 Checking the status of inference endpoint credit-hyper-service.
# Succeeded
# ACI service creation operation finished, operation "Succeeded"

# %%
scoring_uri = service.scoring_uri

print(f'\nservice state: {service.state}\n')
print(f'scoring URI: \n{service.scoring_uri}\n')
print(f'swagger URI: \n{service.swagger_uri}\n')

print(service.scoring_uri)
print(service.swagger_uri)
# Out:
# service state: Healthy
#
# scoring URI:
# http://139d21ba-9a16-4b61-a0c2-007cb32711d2.westeurope.azurecontainer.io/score
#
# swagger URI:
# http://139d21ba-9a16-4b61-a0c2-007cb32711d2.westeurope.azurecontainer.io/swagger.json
#
# http://139d21ba-9a16-4b61-a0c2-007cb32711d2.westeurope.azurecontainer.io/score
# http://139d21ba-9a16-4b61-a0c2-007cb32711d2.westeurope.azurecontainer.io/swagger.json

# %% [markdown]
# TODO: In the cell below, send a request to the web service you deployed to test it.

# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler, Normalizer
from sklearn.model_selection import train_test_split


def standardise_col_names(df):
    df.columns = df.columns.str.lower().str.strip().str.replace(' ', '_')
    return df

def preprocess_quant_features(quant_df: pd.DataFrame, method):

    if method == 'mixmaxScaler':
        scaler = MinMaxScaler().fit(quant_df)
        trans_df = scaler.transform(quant_df)
        return trans_df

    elif method == 'standardScaler':
        scaler = StandardScaler().fit(quant_df)
        trans_df = scaler.transform(quant_df)
        return trans_df

    elif method == 'robustScaler':
        scaler = RobustScaler().fit(quant_df)
        trans_df = scaler.transform(quant_df)
        return trans_df
    elif method == 'normalisation':
        scaler = Normalizer().fit(quant_df)
        trans_df = scaler.transform(quant_df)
        return trans_df
    else:
        print('Choose one of the following: minmaxScaler, standardScaler, robustScaler or normalisation')


def preprocess_cat_features(cat_df: pd.DataFrame, drop_one = True):

    col_names = cat_df.columns
    if drop_one:
        trans_df = pd.DataFrame(pd.get_dummies(cat_df, prefix= col_names, prefix_sep = '_',
                                              columns = col_names, drop_first = True))
    else:
        trans_df = pd.DataFrame(pd.get_dummies(cat_df, prefix= col_names, prefix_sep = '_',
                                              columns = col_names))

    return trans_df

def clean_data(df):

    # standardise column names
    df = standardise_col_names(df)

    # use OHE on categorical columns
    cat_df = preprocess_cat_features(df[['sex', 'education', 'marriage', 'pay_0',
                                        'pay_2', 'pay_3', 'pay_4', 'pay_5', 'pay_6']]).reset_index().drop('index', axis=1)

    # standardise numerical columns using robust scaler
    num_df = pd.DataFrame(preprocess_quant_features(df[[x for x in df.columns if x not in ['sex', 'education', 'marriage', 'pay_0',
                                        'pay_2', 'pay_3', 'pay_4', 'pay_5', 'pay_6','default.payment.next.month']]], 'robustScaler'),
                     columns=[x for x in df.columns if x not in ['sex', 'education', 'marriage', 'pay_0',
                                        'pay_2', 'pay_3', 'pay_4', 'pay_5', 'pay_6',
                                        'default.payment.next.month']]).reset_index().drop('index', axis=1)

    # combine both categorical and numerical
    trans_df = pd.concat([num_df, cat_df], axis=1)
    y_df = df.pop('default.payment.next.month')

    return trans_df, y_df

# %%
    df = pd.read_csv('./UCI_Credit_Card.csv')
    x, y = clean_data(df)

    # Split data into train and test sets
    x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=42)

# %%
tosend = x_test[:2].values.tolist()
tosend = [tosend[0][:],tosend[1][:]]
# Out:
# 82

# %%
import requests
import json

data = json.dumps({"data":tosend})
headers = {'Content-Type':'application/json'}

response = requests.post(scoring_uri,data,headers=headers)
print(response.text)
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): 139d21ba-9a16-4b61-a0c2-007cb32711d2.westeurope.azurecontainer.io:80
# DEBUG:urllib3.connectionpool:http://139d21ba-9a16-4b61-a0c2-007cb32711d2.westeurope.azurecontainer.io:80 "POST /score HTTP/1.1" 200 6
# [0, 0]

# %% [markdown]
# TODO: In the cell below, print the logs of the web service and delete the service

# %%
print('Status code:',response.status_code)

print(service.get_logs())
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): 127.0.1.1:46808
# DEBUG:urllib3.connectionpool:http://127.0.1.1:46808 "GET /MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01 HTTP/1.1" 200 2018
# DEBUG:msrestazure.azure_active_directory:MSI: Retrieving a token from http://127.0.1.1:46808/MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01
# DEBUG:msrestazure.azure_active_directory:MSI: token retrieved
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): 127.0.1.1:46808
# DEBUG:urllib3.connectionpool:http://127.0.1.1:46808 "GET /MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01 HTTP/1.1" 200 2018
# DEBUG:msrestazure.azure_active_directory:MSI: Retrieving a token from http://127.0.1.1:46808/MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01
# DEBUG:msrestazure.azure_active_directory:MSI: token retrieved
# DEBUG:azureml._restclient.clientbase:ClientBase: Calling get with url None
# DEBUG:urllib3.connectionpool:Resetting dropped connection: westeurope.modelmanagement.azureml.net
# DEBUG:urllib3.connectionpool:https://westeurope.modelmanagement.azureml.net:443 "GET /modelmanagement/v1.0/subscriptions/9d6e9855-22d9-4bd1-9b10-1f48fc786ab7/resourceGroups/udacity_capstone/providers/Microsoft.MachineLearningServices/workspaces/udacitycapstone/services/credit-hyper-service/logs?tail=5000&init=False HTTP/1.1" 200 None
# Status code: 200
# 2021-11-13T16:47:35,119769100+00:00 - gunicorn/run
# Dynamic Python package installation is disabled.
# Starting HTTP server
# 2021-11-13T16:47:35,121393900+00:00 - rsyslog/run
# 2021-11-13T16:47:35,147059000+00:00 - iot-server/run
# 2021-11-13T16:47:35,146482300+00:00 - nginx/run
# EdgeHubConnectionString and IOTEDGE_IOTHUBHOSTNAME are not set. Exiting...
# 2021-11-13T16:47:35,531853300+00:00 - iot-server/finish 1 0
# 2021-11-13T16:47:35,533568200+00:00 - Exit code 1 is normal. Not restarting iot-server.
# Starting gunicorn 20.1.0
# Listening at: http://127.0.0.1:31311 (64)
# Using worker: sync
# worker timeout is set to 300
# Booting worker with pid: 92
# SPARK_HOME not set. Skipping PySpark Initialization.
# Initializing logger
# 2021-11-13 16:47:39,037 | root | INFO | Starting up app insights client
# logging socket was found. logging is available.
# logging socket was found. logging is available.
# 2021-11-13 16:47:39,042 | root | INFO | Starting up request id generator
# 2021-11-13 16:47:39,042 | root | INFO | Starting up app insight hooks
# 2021-11-13 16:47:39,042 | root | INFO | Invoking user's init function
# 2021-11-13 16:47:39,971 | root | INFO | Users's init has completed successfully
# 2021-11-13 16:47:39,977 | root | INFO | Skipping middleware: dbg_model_info as it's not enabled.
# 2021-11-13 16:47:39,978 | root | INFO | Skipping middleware: dbg_resource_usage as it's not enabled.
# 2021-11-13 16:47:39,981 | root | INFO | Scoring timeout is found from os.environ: 60000 ms
# 2021-11-13 16:48:45,797 | root | INFO | Swagger file not present
# 2021-11-13 16:48:45,797 | root | INFO | 404
# 127.0.0.1 - - [13/Nov/2021:16:48:45 +0000] "GET /swagger.json HTTP/1.0" 404 19 "-" "Go-http-client/1.1"
# 2021-11-13 16:48:48,729 | root | INFO | Swagger file not present
# 2021-11-13 16:48:48,730 | root | INFO | 404
# 127.0.0.1 - - [13/Nov/2021:16:48:48 +0000] "GET /swagger.json HTTP/1.0" 404 19 "-" "Go-http-client/1.1"
# 2021-11-13 16:50:42,990 | root | INFO | Scoring Timer is set to 60.0 seconds
# 2021-11-13 16:50:43,001 | root | INFO | 200
# 127.0.0.1 - - [13/Nov/2021:16:50:42 +0000] "POST /score HTTP/1.0" 200 81 "-" "python-requests/2.26.0"
# 2021-11-13 16:58:35,230 | root | INFO | Scoring Timer is set to 60.0 seconds
# 2021-11-13 16:58:35,243 | root | INFO | 200
# 127.0.0.1 - - [13/Nov/2021:16:58:35 +0000] "POST /score HTTP/1.0" 200 80 "-" "python-requests/2.26.0"
# 2021-11-13 17:03:40,020 | root | INFO | Scoring Timer is set to 60.0 seconds
# 2021-11-13 17:03:40,028 | root | INFO | 200
# 127.0.0.1 - - [13/Nov/2021:17:03:40 +0000] "POST /score HTTP/1.0" 200 80 "-" "python-requests/2.26.0"
# 2021-11-13 17:05:29,432 | root | INFO | Scoring Timer is set to 60.0 seconds
# 2021-11-13 17:05:29,439 | root | INFO | 200
# 127.0.0.1 - - [13/Nov/2021:17:05:29 +0000] "POST /score HTTP/1.0" 200 80 "-" "python-requests/2.26.0"
# 2021-11-13 17:06:09,055 | root | INFO | Scoring Timer is set to 60.0 seconds
# 2021-11-13 17:06:09,065 | root | INFO | 200
# 127.0.0.1 - - [13/Nov/2021:17:06:09 +0000] "POST /score HTTP/1.0" 200 81 "-" "python-requests/2.26.0"
# 2021-11-13 17:06:55,008 | root | INFO | Scoring Timer is set to 60.0 seconds
# 2021-11-13 17:06:55,027 | root | INFO | 200
# 127.0.0.1 - - [13/Nov/2021:17:06:55 +0000] "POST /score HTTP/1.0" 200 81 "-" "python-requests/2.26.0"
# 2021-11-13 17:11:51,987 | root | INFO | Scoring Timer is set to 60.0 seconds
# 2021-11-13 17:11:52,005 | root | INFO | 200
# 127.0.0.1 - - [13/Nov/2021:17:11:52 +0000] "POST /score HTTP/1.0" 200 6 "-" "python-requests/2.26.0"

# %%
service.delete()
cpu_cluster.delete()
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): 127.0.1.1:46808
# DEBUG:urllib3.connectionpool:http://127.0.1.1:46808 "GET /MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01 HTTP/1.1" 200 2018
# DEBUG:msrestazure.azure_active_directory:MSI: Retrieving a token from http://127.0.1.1:46808/MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01
# DEBUG:msrestazure.azure_active_directory:MSI: token retrieved
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): 127.0.1.1:46808
# DEBUG:urllib3.connectionpool:http://127.0.1.1:46808 "GET /MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01 HTTP/1.1" 200 2018
# DEBUG:msrestazure.azure_active_directory:MSI: Retrieving a token from http://127.0.1.1:46808/MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01
# DEBUG:msrestazure.azure_active_directory:MSI: token retrieved
# DEBUG:azureml._restclient.clientbase:ClientBase: Calling post with url None
# DEBUG:urllib3.connectionpool:https://westeurope.modelmanagement.azureml.net:443 "POST /modelmanagement/v1.0/subscriptions/9d6e9855-22d9-4bd1-9b10-1f48fc786ab7/resourceGroups/udacity_capstone/providers/Microsoft.MachineLearningServices/workspaces/udacitycapstone/services/validate HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): 127.0.1.1:46808
# DEBUG:urllib3.connectionpool:http://127.0.1.1:46808 "GET /MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01 HTTP/1.1" 200 2018
# DEBUG:msrestazure.azure_active_directory:MSI: Retrieving a token from http://127.0.1.1:46808/MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01
# DEBUG:msrestazure.azure_active_directory:MSI: token retrieved
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): 127.0.1.1:46808
# DEBUG:urllib3.connectionpool:http://127.0.1.1:46808 "GET /MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01 HTTP/1.1" 200 2018
# DEBUG:msrestazure.azure_active_directory:MSI: Retrieving a token from http://127.0.1.1:46808/MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01
# DEBUG:msrestazure.azure_active_directory:MSI: token retrieved
# DEBUG:azureml._restclient.clientbase:ClientBase: Calling delete with url None
# DEBUG:urllib3.connectionpool:https://westeurope.modelmanagement.azureml.net:443 "DELETE /modelmanagement/v1.0/subscriptions/9d6e9855-22d9-4bd1-9b10-1f48fc786ab7/resourceGroups/udacity_capstone/providers/Microsoft.MachineLearningServices/workspaces/udacitycapstone/services/credit-hyper-service HTTP/1.1" 200 0
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): 127.0.1.1:46808
# DEBUG:urllib3.connectionpool:http://127.0.1.1:46808 "GET /MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01 HTTP/1.1" 200 2018
# DEBUG:msrestazure.azure_active_directory:MSI: Retrieving a token from http://127.0.1.1:46808/MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01
# DEBUG:msrestazure.azure_active_directory:MSI: token retrieved
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): 127.0.1.1:46808
# DEBUG:urllib3.connectionpool:http://127.0.1.1:46808 "GET /MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01 HTTP/1.1" 200 2018
# DEBUG:msrestazure.azure_active_directory:MSI: Retrieving a token from http://127.0.1.1:46808/MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01
# DEBUG:msrestazure.azure_active_directory:MSI: token retrieved
# DEBUG:azureml._restclient.clientbase:ClientBase: Calling delete with url None
# DEBUG:urllib3.connectionpool:Resetting dropped connection: management.azure.com
# DEBUG:urllib3.connectionpool:https://management.azure.com:443 "DELETE //subscriptions/9d6e9855-22d9-4bd1-9b10-1f48fc786ab7/resourceGroups/udacity_capstone/providers/Microsoft.MachineLearningServices/workspaces/udacitycapstone/computes/cpu-cluster?api-version=2020-02-02&underlyingResourceAction=delete HTTP/1.1" 202 0

# %%
model.delete()
# Out:
# DEBUG:azureml.ModelsClient.delete-async:False:[START]
# DEBUG:azureml.ModelsClient:ClientBase: Calling delete with url /modelmanagement/v1.0/subscriptions/{subscriptionId}/resourceGroups/{resourceGroup}/providers/Microsoft.MachineLearningServices/workspaces/{workspace}/models/{id}
# DEBUG:msrest.service_client:Accept header absent and forced to application/json
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): 127.0.1.1:46808
# DEBUG:urllib3.connectionpool:http://127.0.1.1:46808 "GET /MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01 HTTP/1.1" 200 2018
# DEBUG:msrestazure.azure_active_directory:MSI: Retrieving a token from http://127.0.1.1:46808/MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01
# DEBUG:msrestazure.azure_active_directory:MSI: token retrieved
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): 127.0.1.1:46808
# DEBUG:urllib3.connectionpool:http://127.0.1.1:46808 "GET /MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01 HTTP/1.1" 200 2018
# DEBUG:msrestazure.azure_active_directory:MSI: Retrieving a token from http://127.0.1.1:46808/MSI/auth/?resource=https://management.core.windows.net/&api-version=2017-09-01
# DEBUG:msrestazure.azure_active_directory:MSI: token retrieved
# DEBUG:msrest.http_logger:Request URL: 'https://westeurope.modelmanagement.azureml.net/modelmanagement/v1.0/subscriptions/9d6e9855-22d9-4bd1-9b10-1f48fc786ab7/resourceGroups/udacity_capstone/providers/Microsoft.MachineLearningServices/workspaces/udacitycapstone/models/credit_hyperdrive_model%3A1'
# DEBUG:msrest.http_logger:Request method: 'DELETE'
# DEBUG:msrest.http_logger:Request headers:
# DEBUG:msrest.http_logger:    'Accept': 'application/json'
# DEBUG:msrest.http_logger:    'Content-Type': 'application/json; charset=utf-8'
# DEBUG:msrest.http_logger:    'User-Agent': 'DSVM_workstation/47506801_21.09.20 azureml-sdk-core/1.34.0'
# DEBUG:msrest.http_logger:    'x-ms-client-session-id': '31df6067-7949-4077-acf2-97c30a607df7'
# DEBUG:msrest.http_logger:    'x-ms-client-request-id': '559412d5-7497-47a9-9df8-f228952368b3'
# DEBUG:msrest.http_logger:    'request-id': '559412d5-7497-47a9-9df8-f228952368b3'
# DEBUG:msrest.http_logger:Request body:
# DEBUG:msrest.http_logger:None
# DEBUG:msrest.universal_http:Configuring redirects: allow=True, max=30
# DEBUG:msrest.universal_http:Configuring request: timeout=100, verify=True, cert=None
# DEBUG:msrest.universal_http:Configuring proxies: ''
# DEBUG:msrest.universal_http:Evaluate proxies against ENV settings: True
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): westeurope.modelmanagement.azureml.net:443
# DEBUG:urllib3.connectionpool:https://westeurope.modelmanagement.azureml.net:443 "DELETE /modelmanagement/v1.0/subscriptions/9d6e9855-22d9-4bd1-9b10-1f48fc786ab7/resourceGroups/udacity_capstone/providers/Microsoft.MachineLearningServices/workspaces/udacitycapstone/models/credit_hyperdrive_model%3A1 HTTP/1.1" 200 0
# DEBUG:msrest.http_logger:Response status: 200
# DEBUG:msrest.http_logger:Response headers:
# DEBUG:msrest.http_logger:    'Date': 'Sat, 13 Nov 2021 17:13:31 GMT'
# DEBUG:msrest.http_logger:    'Content-Length': '0'
# DEBUG:msrest.http_logger:    'Connection': 'keep-alive'
# DEBUG:msrest.http_logger:    'Request-Context': 'appId=cid-v1:6a27ce65-5555-41a3-85f7-b7a1ce31fd6b'
# DEBUG:msrest.http_logger:    'x-ms-response-type': 'standard'
# DEBUG:msrest.http_logger:    'x-ms-client-request-id': '559412d5-7497-47a9-9df8-f228952368b3'
# DEBUG:msrest.http_logger:    'x-ms-client-session-id': '31df6067-7949-4077-acf2-97c30a607df7'
# DEBUG:msrest.http_logger:    'Strict-Transport-Security': 'max-age=15724800; includeSubDomains; preload'
# DEBUG:msrest.http_logger:    'X-Content-Type-Options': 'nosniff'
# DEBUG:msrest.http_logger:    'x-request-time': '0.420'
# DEBUG:msrest.http_logger:Response content:
# DEBUG:msrest.http_logger:
# DEBUG:azureml.ModelsClient.delete-async:False:[STOP]

# %% [markdown]
# **Submission Checklist**
# - I have registered the model.
# - I have deployed the model with the best accuracy as a webservice.
# - I have tested the webservice by sending a request to the model endpoint.
# - I have deleted the webservice and shutdown all the computes that I have used.
# - I have taken a screenshot showing the model endpoint as active.
# - The project includes a file containing the environment details.
